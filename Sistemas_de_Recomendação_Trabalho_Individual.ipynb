# %% [markdown]
# ## Imports and downloading data

# %%
# !pip install caserecommender
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting caserecommender
#   Downloading CaseRecommender-1.1.1-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 7.5 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from caserecommender) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from caserecommender) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from caserecommender) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from caserecommender) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->caserecommender) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->caserecommender) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->caserecommender) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->caserecommender) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->caserecommender) (1.1.0)
# Installing collected packages: caserecommender
# Successfully installed caserecommender-1.1.1

# %%
import nltk
import json
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from google.colab import files, drive
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import pairwise_distances
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import PAIRWISE_DISTANCE_FUNCTIONS

# Recommender algorithms
from caserec.recommenders.rating_prediction.svd import SVD
from caserec.recommenders.rating_prediction.userknn import UserKNN
from caserec.recommenders.rating_prediction.itemknn import ItemKNN
from caserec.recommenders.rating_prediction.random_rec import RandomRec
from caserec.recommenders.rating_prediction.most_popular import MostPopular
from caserec.recommenders.rating_prediction.item_attribute_knn import ItemAttributeKNN
from caserec.recommenders.rating_prediction.matrixfactorization import MatrixFactorization

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# rm: cannot remove '/root/.kaggle': No such file or directory

# %%
# !kaggle competitions download -c scc5966
# !mkdir competition
# !mkdir train_outputs
# !unzip scc5966.zip -d competition/
# Out:
# Downloading scc5966.zip to /content
#  29% 5.00M/17.5M [00:00<00:00, 37.0MB/s]
# 100% 17.5M/17.5M [00:00<00:00, 76.7MB/s]
# Archive:  scc5966.zip
#   inflating: competition/movie_reviews.csv
#   inflating: competition/movies_data.csv
#   inflating: competition/test_data.csv
#   inflating: competition/train_data .csv
#   inflating: competition/users_data.csv

# %% [markdown]
# ## Reading and preparing data

# %%
df_users = pd.read_csv('competition/users_data.csv')
df_train = pd.read_csv('competition/train_data .csv')
df_test = pd.read_csv('competition/test_data.csv')

df_train.drop(columns=['timestamp'], inplace=True)
df_test.drop(columns=['timestamp'], inplace=True)

df_train.to_csv('full_train.dat', index=False, header=False, sep='\t')
df_test[['user_id', 'movie_id', 'id']].to_csv('full_test.dat', index=False, header=False, sep='\t')

df_test.set_index(['user_id', 'movie_id'], inplace=True)

# %%
train = df_train.sample(frac=.1, random_state=3)

train, eval = train_test_split(train,
                               test_size=.3,
                               random_state=7)

train.to_csv('train.dat', index=False, header=False, sep='\t')
eval.to_csv('test.dat', index=False, header=False, sep='\t')

eval = eval.reset_index()
eval.set_index(['user_id', 'movie_id'], inplace=True)

# %% [markdown]
# # Prediction Algorithms

# %% [markdown]
# ## Cold Starting

# %%
def cold_start(results, train_set, target_key, cold_key, method='average'):
    cold_group = train_set.groupby(cold_key)

    if method == 'average': colded = cold_group.mean()
    elif method == 'mode': colded = cold_group.agg( lambda x: pd.Series.mode(x)[0] )
    else: colded = cold_group.agg( lambda x: np.random.randint(0, 51) / 10 ) # Random

    colded = colded[['rating']].rename(columns={'rating': 'colded'})
    
    results = results.join(colded, how='left', on=cold_key)

    results.rating = np.where(results.rating.isna(), results.colded, results.rating)
    results = results.drop(columns=['colded'])
    
    return results

# %% [markdown]
# ## Baseline

# %%
def baseline_predict(train, test, global_bias, user_const, item_const):

    print(f"\n\nStarting training on baseline with {user_const} user bias and {item_const} item bias")

    train_output = f'train_outputs/basline_{user_const}_userConstant_{item_const}_itemConstant.dat'
    result_output = f'result_outputs/results_{train_output}'

    users_bias = train.groupby('user_id').agg({'rating': ['sum', 'count']})
    users_bias['user_bias'] = (users_bias[('rating', 'sum')]) / (user_const + users_bias[('rating', 'count')])
    users_bias = users_bias[['user_bias']]

    movies_bias = train.groupby('movie_id').agg({'rating': ['sum', 'count']})
    movies_bias['movie_bias'] = (movies_bias[('rating', 'sum')]) / (item_const + movies_bias[('rating', 'count')])
    movies_bias = movies_bias[['movie_bias']]

    results = test.join(users_bias, how='left') \
                        .join(movies_bias, how='left')

    results.fillna(0, inplace=True)
    results.columns = ['id', 'user_bias', 'movie_bias']
    results['rating'] = global_bias + results.user_bias + results.movie_bias

    return results

def baseline_run_tests(train, test, consts):
    test_results_file = 'test_results_Baseline.csv'

    base_eval = test.copy()
    base_train = train.copy()

    global_bias = train.rating.mean()
    base_train.rating = base_train.rating - global_bias
    
    real = base_eval.reset_index().rating
    base_eval.drop(columns=['rating'], inplace=True)

    for u_const in consts:
        for i_const in consts:
            preds = baseline_predict(base_train, base_eval, global_bias, u_const, i_const)
            pred = preds.reset_index().rating

            rmse = mean_squared_error(real, pred, squared=False)
            print(f'RMSE for baseline method constants {u_const} and {i_const}: {rmse}')

            with open(test_results_file, 'a') as f:
                data = f"baseline,{u_const},{i_const},{rmse}\n"
                f.write(data)

    files.download(test_results_file)

# %%
constants = [1, 2, 5, 10, 15, 20, 25, 50, 100, 200]
baseline_run_tests(train, eval, constants)
# Out:
# Starting training on baseline with 1 user bias and 1 item bias
# RMSE for baseline method constants 1 and 1: 1.002819020538464
#
#
# Starting training on baseline with 1 user bias and 2 item bias
# RMSE for baseline method constants 1 and 2: 0.9983422290990647
#
#
# Starting training on baseline with 1 user bias and 5 item bias
# RMSE for baseline method constants 1 and 5: 0.9959905129978041
#
#
# Starting training on baseline with 1 user bias and 10 item bias
# RMSE for baseline method constants 1 and 10: 0.999105107319214
#
#
# Starting training on baseline with 1 user bias and 15 item bias
# RMSE for baseline method constants 1 and 15: 1.0032184683328935
#
#
# Starting training on baseline with 1 user bias and 20 item bias
# RMSE for baseline method constants 1 and 20: 1.0070855186247278
#
#
# Starting training on baseline with 1 user bias and 25 item bias
# RMSE for baseline method constants 1 and 25: 1.0105524453041606
#
#
# Starting training on baseline with 1 user bias and 50 item bias
# RMSE for baseline method constants 1 and 50: 1.0231570800713303
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# Starting training on baseline with 1 user bias and 100 item bias
# RMSE for baseline method constants 1 and 100: 1.0367258641887767
#
#
# Starting training on baseline with 1 user bias and 200 item bias
# RMSE for baseline method constants 1 and 200: 1.0489321550622592
#
#
# Starting training on baseline with 2 user bias and 1 item bias
# RMSE for baseline method constants 2 and 1: 0.9925800060938095
#
#
# Starting training on baseline with 2 user bias and 2 item bias
# RMSE for baseline method constants 2 and 2: 0.9882057002110461
#
#
# Starting training on baseline with 2 user bias and 5 item bias
# RMSE for baseline method constants 2 and 5: 0.9861279344067141
#
#
# Starting training on baseline with 2 user bias and 10 item bias
# RMSE for baseline method constants 2 and 10: 0.989580961457939
#
#
# Starting training on baseline with 2 user bias and 15 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 2 and 15: 0.9939430917603305
#
#
# Starting training on baseline with 2 user bias and 20 item bias
# RMSE for baseline method constants 2 and 20: 0.9980050054331797
#
#
# Starting training on baseline with 2 user bias and 25 item bias
# RMSE for baseline method constants 2 and 25: 1.001630902165935
#
#
# Starting training on baseline with 2 user bias and 50 item bias
# RMSE for baseline method constants 2 and 50: 1.0147476345483772
#
#
# Starting training on baseline with 2 user bias and 100 item bias
# RMSE for baseline method constants 2 and 100: 1.0287990719576743
#
#
# Starting training on baseline with 2 user bias and 200 item bias
# RMSE for baseline method constants 2 and 200: 1.0413952241939555
#
#
# Starting training on baseline with 5 user bias and 1 item bias
# RMSE for baseline method constants 5 and 1: 0.9812322872934646
#
#
# Starting training on baseline with 5 user bias and 2 item bias
# RMSE for baseline method constants 5 and 2: 0.9771369522561877
#
#
# Starting training on baseline with 5 user bias and 5 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 5 and 5: 0.9756793145491701
#
#
# Starting training on baseline with 5 user bias and 10 item bias
# RMSE for baseline method constants 5 and 10: 0.9798089370564625
#
#
# Starting training on baseline with 5 user bias and 15 item bias
# RMSE for baseline method constants 5 and 15: 0.9846359539608728
#
#
# Starting training on baseline with 5 user bias and 20 item bias
# RMSE for baseline method constants 5 and 20: 0.9890486240620275
#
#
# Starting training on baseline with 5 user bias and 25 item bias
# RMSE for baseline method constants 5 and 25: 0.9929535281776686
#
#
# Starting training on baseline with 5 user bias and 50 item bias
# RMSE for baseline method constants 5 and 50: 1.0069338277551327
#
#
# Starting training on baseline with 5 user bias and 100 item bias
# RMSE for baseline method constants 5 and 100: 1.0217598017835328
#
#
# Starting training on baseline with 5 user bias and 200 item bias
# RMSE for baseline method constants 5 and 200: 1.0349589080189197
#
#
# Starting training on baseline with 10 user bias and 1 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 10 and 1: 0.9771784565358801
#
#
# Starting training on baseline with 10 user bias and 2 item bias
# RMSE for baseline method constants 10 and 2: 0.9734251883659387
#
#
# Starting training on baseline with 10 user bias and 5 item bias
# RMSE for baseline method constants 10 and 5: 0.9726442730300112
#
#
# Starting training on baseline with 10 user bias and 10 item bias
# RMSE for baseline method constants 10 and 10: 0.9774389250108987
#
#
# Starting training on baseline with 10 user bias and 15 item bias
# RMSE for baseline method constants 10 and 15: 0.982692347137965
#
#
# Starting training on baseline with 10 user bias and 20 item bias
# RMSE for baseline method constants 10 and 20: 0.9874132379787802
#
#
# Starting training on baseline with 10 user bias and 25 item bias
# RMSE for baseline method constants 10 and 25: 0.9915558749381392
#
#
# Starting training on baseline with 10 user bias and 50 item bias
# RMSE for baseline method constants 10 and 50: 1.00623481623983
#
#
# Starting training on baseline with 10 user bias and 100 item bias
# RMSE for baseline method constants 10 and 100: 1.0216451020898945
#
#
# Starting training on baseline with 10 user bias and 200 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 10 and 200: 1.0352743481011466
#
#
# Starting training on baseline with 15 user bias and 1 item bias
# RMSE for baseline method constants 15 and 1: 0.9773099750468829
#
#
# Starting training on baseline with 15 user bias and 2 item bias
# RMSE for baseline method constants 15 and 2: 0.9738034064082169
#
#
# Starting training on baseline with 15 user bias and 5 item bias
# RMSE for baseline method constants 15 and 5: 0.9734818873294816
#
#
# Starting training on baseline with 15 user bias and 10 item bias
# RMSE for baseline method constants 15 and 10: 0.9786994641756901
#
#
# Starting training on baseline with 15 user bias and 15 item bias
# RMSE for baseline method constants 15 and 15: 0.9842108713058442
#
#
# Starting training on baseline with 15 user bias and 20 item bias
# RMSE for baseline method constants 15 and 20: 0.9891120451428503
#
#
# Starting training on baseline with 15 user bias and 25 item bias
# RMSE for baseline method constants 15 and 25: 0.9933902025432068
#
#
# Starting training on baseline with 15 user bias and 50 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 15 and 50: 1.0084494596009654
#
#
# Starting training on baseline with 15 user bias and 100 item bias
# RMSE for baseline method constants 15 and 100: 1.0241567395195248
#
#
# Starting training on baseline with 15 user bias and 200 item bias
# RMSE for baseline method constants 15 and 200: 1.0379917097580609
#
#
# Starting training on baseline with 20 user bias and 1 item bias
# RMSE for baseline method constants 20 and 1: 0.9785534559271822
#
#
# Starting training on baseline with 20 user bias and 2 item bias
# RMSE for baseline method constants 20 and 2: 0.9752364146175062
#
#
# Starting training on baseline with 20 user bias and 5 item bias
# RMSE for baseline method constants 20 and 5: 0.975256515908483
#
#
# Starting training on baseline with 20 user bias and 10 item bias
# RMSE for baseline method constants 20 and 10: 0.9807765943245486
#
#
# Starting training on baseline with 20 user bias and 15 item bias
# RMSE for baseline method constants 20 and 15: 0.9864666517561523
#
#
# Starting training on baseline with 20 user bias and 20 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 20 and 20: 0.991489794560731
#
#
# Starting training on baseline with 20 user bias and 25 item bias
# RMSE for baseline method constants 20 and 25: 0.9958579562982415
#
#
# Starting training on baseline with 20 user bias and 50 item bias
# RMSE for baseline method constants 20 and 50: 1.0111611321380474
#
#
# Starting training on baseline with 20 user bias and 100 item bias
# RMSE for baseline method constants 20 and 100: 1.0270483758611397
#
#
# Starting training on baseline with 20 user bias and 200 item bias
# RMSE for baseline method constants 20 and 200: 1.0410012030545894
#
#
# Starting training on baseline with 25 user bias and 1 item bias
# RMSE for baseline method constants 25 and 1: 0.9801230052794078
#
#
# Starting training on baseline with 25 user bias and 2 item bias
# RMSE for baseline method constants 25 and 2: 0.9769577312752866
#
#
# Starting training on baseline with 25 user bias and 5 item bias
# RMSE for baseline method constants 25 and 5: 0.977245567186109
#
#
# Starting training on baseline with 25 user bias and 10 item bias
# RMSE for baseline method constants 25 and 10: 0.9829963492191311
#
#
# Starting training on baseline with 25 user bias and 15 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 25 and 15: 0.98881943430633
#
#
# Starting training on baseline with 25 user bias and 20 item bias
# RMSE for baseline method constants 25 and 20: 0.9939317845686862
#
#
# Starting training on baseline with 25 user bias and 25 item bias
# RMSE for baseline method constants 25 and 25: 0.9983648146511862
#
#
# Starting training on baseline with 25 user bias and 50 item bias
# RMSE for baseline method constants 25 and 50: 1.0138387846177053
#
#
# Starting training on baseline with 25 user bias and 100 item bias
# RMSE for baseline method constants 25 and 100: 1.0298458027610682
#
#
# Starting training on baseline with 25 user bias and 200 item bias
# RMSE for baseline method constants 25 and 200: 1.0438728300174078
#
#
# Starting training on baseline with 50 user bias and 1 item bias
# RMSE for baseline method constants 50 and 1: 0.9875588345946742
#
#
# Starting training on baseline with 50 user bias and 2 item bias
# RMSE for baseline method constants 50 and 2: 0.984861427954004
#
#
# Starting training on baseline with 50 user bias and 5 item bias
# RMSE for baseline method constants 50 and 5: 0.9859478207095146
#
#
# Starting training on baseline with 50 user bias and 10 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 50 and 10: 0.992356948694215
#
#
# Starting training on baseline with 50 user bias and 15 item bias
# RMSE for baseline method constants 50 and 15: 0.9985443895773795
#
#
# Starting training on baseline with 50 user bias and 20 item bias
# RMSE for baseline method constants 50 and 20: 1.0038933324065276
#
#
# Starting training on baseline with 50 user bias and 25 item bias
# RMSE for baseline method constants 50 and 25: 1.0084937501013398
#
#
# Starting training on baseline with 50 user bias and 50 item bias
# RMSE for baseline method constants 50 and 50: 1.0243840642634292
#
#
# Starting training on baseline with 50 user bias and 100 item bias
# RMSE for baseline method constants 50 and 100: 1.0406520765767207
#
#
# Starting training on baseline with 50 user bias and 200 item bias
# RMSE for baseline method constants 50 and 200: 1.0548187986117012
#
#
# Starting training on baseline with 100 user bias and 1 item bias
# RMSE for baseline method constants 100 and 1: 0.9966650321027974
#
#
# Starting training on baseline with 100 user bias and 2 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 100 and 2: 0.9943735387732567
#
#
# Starting training on baseline with 100 user bias and 5 item bias
# RMSE for baseline method constants 100 and 5: 0.9961252431699398
#
#
# Starting training on baseline with 100 user bias and 10 item bias
# RMSE for baseline method constants 100 and 10: 1.0030518888536886
#
#
# Starting training on baseline with 100 user bias and 15 item bias
# RMSE for baseline method constants 100 and 15: 1.009509469119859
#
#
# Starting training on baseline with 100 user bias and 20 item bias
# RMSE for baseline method constants 100 and 20: 1.015025348013379
#
#
# Starting training on baseline with 100 user bias and 25 item bias
# RMSE for baseline method constants 100 and 25: 1.0197386593336626
#
#
# Starting training on baseline with 100 user bias and 50 item bias
# RMSE for baseline method constants 100 and 50: 1.035882014199841
#
#
# Starting training on baseline with 100 user bias and 100 item bias
# RMSE for baseline method constants 100 and 100: 1.0522716669362706
#
#
# Starting training on baseline with 100 user bias and 200 item bias
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# RMSE for baseline method constants 100 and 200: 1.0664742937734388
#
#
# Starting training on baseline with 200 user bias and 1 item bias
# RMSE for baseline method constants 200 and 1: 1.0048034674488977
#
#
# Starting training on baseline with 200 user bias and 2 item bias
# RMSE for baseline method constants 200 and 2: 1.0028116462108145
#
#
# Starting training on baseline with 200 user bias and 5 item bias
# RMSE for baseline method constants 200 and 5: 1.0050401219454987
#
#
# Starting training on baseline with 200 user bias and 10 item bias
# RMSE for baseline method constants 200 and 10: 1.0123212696832267
#
#
# Starting training on baseline with 200 user bias and 15 item bias
# RMSE for baseline method constants 200 and 15: 1.0189550238084213
#
#
# Starting training on baseline with 200 user bias and 20 item bias
# RMSE for baseline method constants 200 and 20: 1.0245749539142943
#
#
# Starting training on baseline with 200 user bias and 25 item bias
# RMSE for baseline method constants 200 and 25: 1.029355550217501
#
#
# Starting training on baseline with 200 user bias and 50 item bias
# RMSE for baseline method constants 200 and 50: 1.0456327283398066
#
#
# Starting training on baseline with 200 user bias and 100 item bias
# RMSE for baseline method constants 200 and 100: 1.0620617935133432
#
#
# Starting training on baseline with 200 user bias and 200 item bias
# RMSE for baseline method constants 200 and 200: 1.0762504677559845
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,

# %% [markdown]
# ## Filtragem Colaborativa

# %%
def fc_predict(func, train, test, k_neighbors, similarity, train_file):
    func_name = func.__name__
    
    print(f"\n\nStarting training on {func_name} with {k_neighbors} neighbors and {similarity} similarity")

    train_output = f'train_outputs/{func_name}_{similarity}_{"default" if k_neighbors is None else k_neighbors}k.dat'
    result_output = f'result_outputs/results_{train_output}'

    func(train_file, output_file=train_output, k_neighbors=k_neighbors,
            similarity_metric=similarity, as_similar_first=True).compute()

    preds = pd.read_csv(train_output, sep='\t', names=['user_id', 'movie_id', 'rating'])
    preds.set_index(['user_id', 'movie_id'], inplace=True)

    results = test.join(preds, how='left').reset_index()
    return results

# %%
def fc_run_tests(train, test, funcs, similarities, k_neighbors, cold_starts):
    test_results_file = 'test_results_FC.csv'
    
    real_ratings = test.reset_index().rating
    to_test = test.drop(columns=['rating'])

    for func in funcs:
        func_name = func.__name__
        for sim in similarities:
            for k in k_neighbors:
                results = fc_predict(func, train, to_test, k, sim, 'train.dat')
                for cold in cold_starts:
                    results = cold_start(results, train, 'movie_id', 'user_id', cold)
                    results = cold_start(results, train, 'user_id', 'movie_id', cold)
                    
                    qtd_nan = results.rating.isna().sum()
                    print(f"{qtd_nan} nan predictions from {results.shape[0]} total")

                    predicted = results.rating

                    used = np.logical_and(~real_ratings.isna(), ~predicted.isna())
                    rmse = mean_squared_error(real_ratings[used], predicted[used], squared=False)

                    msg = f"{func_name} with {k} neighbors, {sim} similarity and {cold} for cold start: RMSE = {rmse}"
                    print(msg)

                    with open(test_results_file, 'a') as f:
                        data = f"{func_name},{k},{sim},{cold},{rmse}\n"
                        f.write(data)

    files.download(test_results_file)

# %%
funcs = [ItemKNN, UserKNN]
cold_starts = ['average', 'mode']
similarities = ['cosine', 'hamming', 'jaccard']
k_neighbors = [1, 10, 50, 150, 300, 500]

fc_run_tests(train, eval, funcs, similarities, k_neighbors, cold_starts)
# Out:
# Starting training on ItemKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.673682 sec
# prediction_time:: 589.049220 sec
# 79 nan predictions from 16074 total
# ItemKNN with 1 neighbors, cosine similarity and average for cold start: RMSE = 1.1028345304483298
# 79 nan predictions from 16074 total
# ItemKNN with 1 neighbors, cosine similarity and mode for cold start: RMSE = 1.1075168172478238
#
#
# Starting training on ItemKNN with 10 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.514815 sec
# prediction_time:: 209.163162 sec
# 79 nan predictions from 16074 total
# ItemKNN with 10 neighbors, cosine similarity and average for cold start: RMSE = 1.2576163469907358
# 79 nan predictions from 16074 total
# ItemKNN with 10 neighbors, cosine similarity and mode for cold start: RMSE = 1.261724365761351
#
#
# Starting training on ItemKNN with 50 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.074725 sec
# prediction_time:: 181.350102 sec
# 79 nan predictions from 16074 total
# ItemKNN with 50 neighbors, cosine similarity and average for cold start: RMSE = 1.2815028233548804
# 79 nan predictions from 16074 total
# ItemKNN with 50 neighbors, cosine similarity and mode for cold start: RMSE = 1.2855345134239262
#
#
# Starting training on ItemKNN with 150 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.166248 sec
# prediction_time:: 183.517453 sec
# 79 nan predictions from 16074 total
# ItemKNN with 150 neighbors, cosine similarity and average for cold start: RMSE = 1.2820061228844852
# 79 nan predictions from 16074 total
# ItemKNN with 150 neighbors, cosine similarity and mode for cold start: RMSE = 1.286036235123595
#
#
# Starting training on ItemKNN with 300 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.093962 sec
# prediction_time:: 179.761034 sec
# 79 nan predictions from 16074 total
# ItemKNN with 300 neighbors, cosine similarity and average for cold start: RMSE = 1.2820061228844852
# 79 nan predictions from 16074 total
# ItemKNN with 300 neighbors, cosine similarity and mode for cold start: RMSE = 1.286036235123595
#
#
# Starting training on ItemKNN with 500 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.023808 sec
# prediction_time:: 180.175745 sec
# 79 nan predictions from 16074 total
# ItemKNN with 500 neighbors, cosine similarity and average for cold start: RMSE = 1.2820061228844852
# 79 nan predictions from 16074 total
# ItemKNN with 500 neighbors, cosine similarity and mode for cold start: RMSE = 1.286036235123595
#
#
# Starting training on ItemKNN with 1 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.837462 sec
# prediction_time:: 821.943226 sec
# 79 nan predictions from 16074 total
# ItemKNN with 1 neighbors, hamming similarity and average for cold start: RMSE = 1.017807065545523
# 79 nan predictions from 16074 total
# ItemKNN with 1 neighbors, hamming similarity and mode for cold start: RMSE = 1.0228786446162366
#
#
# Starting training on ItemKNN with 10 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.841004 sec
# prediction_time:: 246.076764 sec
# 79 nan predictions from 16074 total
# ItemKNN with 10 neighbors, hamming similarity and average for cold start: RMSE = 1.1668863751530492
# 79 nan predictions from 16074 total
# ItemKNN with 10 neighbors, hamming similarity and mode for cold start: RMSE = 1.1713126446237074
#
#
# Starting training on ItemKNN with 50 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.713530 sec
# prediction_time:: 209.690312 sec
# 79 nan predictions from 16074 total
# ItemKNN with 50 neighbors, hamming similarity and average for cold start: RMSE = 1.259890186190901
# 79 nan predictions from 16074 total
# ItemKNN with 50 neighbors, hamming similarity and mode for cold start: RMSE = 1.263990814918251
#
#
# Starting training on ItemKNN with 150 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.615456 sec
# prediction_time:: 209.955338 sec
# 79 nan predictions from 16074 total
# ItemKNN with 150 neighbors, hamming similarity and average for cold start: RMSE = 1.25992183581373
# 79 nan predictions from 16074 total
# ItemKNN with 150 neighbors, hamming similarity and mode for cold start: RMSE = 1.2640223618661977
#
#
# Starting training on ItemKNN with 300 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.819331 sec
# prediction_time:: 206.905768 sec
# 79 nan predictions from 16074 total
# ItemKNN with 300 neighbors, hamming similarity and average for cold start: RMSE = 1.25992183581373
# 79 nan predictions from 16074 total
# ItemKNN with 300 neighbors, hamming similarity and mode for cold start: RMSE = 1.2640223618661977
#
#
# Starting training on ItemKNN with 500 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.731837 sec
# prediction_time:: 206.164093 sec
# 79 nan predictions from 16074 total
# ItemKNN with 500 neighbors, hamming similarity and average for cold start: RMSE = 1.25992183581373
# 79 nan predictions from 16074 total
# ItemKNN with 500 neighbors, hamming similarity and mode for cold start: RMSE = 1.2640223618661977
#
#
# Starting training on ItemKNN with 1 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.727167 sec
# prediction_time:: 521.563072 sec
# 79 nan predictions from 16074 total
# ItemKNN with 1 neighbors, jaccard similarity and average for cold start: RMSE = 1.1930742236035285
# 79 nan predictions from 16074 total
# ItemKNN with 1 neighbors, jaccard similarity and mode for cold start: RMSE = 1.1974036921459377
#
#
# Starting training on ItemKNN with 10 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.837556 sec
# prediction_time:: 182.295755 sec
# 79 nan predictions from 16074 total
# ItemKNN with 10 neighbors, jaccard similarity and average for cold start: RMSE = 1.279154645952683
# 79 nan predictions from 16074 total
# ItemKNN with 10 neighbors, jaccard similarity and mode for cold start: RMSE = 1.2831937138249605
#
#
# Starting training on ItemKNN with 50 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.363682 sec
# prediction_time:: 164.029552 sec
# 79 nan predictions from 16074 total
# ItemKNN with 50 neighbors, jaccard similarity and average for cold start: RMSE = 1.3014368476293354
# 79 nan predictions from 16074 total
# ItemKNN with 50 neighbors, jaccard similarity and mode for cold start: RMSE = 1.3054069738227014
#
#
# Starting training on ItemKNN with 150 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.846250 sec
# prediction_time:: 158.861659 sec
# 79 nan predictions from 16074 total
# ItemKNN with 150 neighbors, jaccard similarity and average for cold start: RMSE = 1.302804429814189
# 79 nan predictions from 16074 total
# ItemKNN with 150 neighbors, jaccard similarity and mode for cold start: RMSE = 1.3067704011344285
#
#
# Starting training on ItemKNN with 300 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.020980 sec
# prediction_time:: 158.177350 sec
# 79 nan predictions from 16074 total
# ItemKNN with 300 neighbors, jaccard similarity and average for cold start: RMSE = 1.302804429814189
# 79 nan predictions from 16074 total
# ItemKNN with 300 neighbors, jaccard similarity and mode for cold start: RMSE = 1.3067704011344285
#
#
# Starting training on ItemKNN with 500 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.881456 sec
# prediction_time:: 157.216245 sec
# 79 nan predictions from 16074 total
# ItemKNN with 500 neighbors, jaccard similarity and average for cold start: RMSE = 1.302804429814189
# 79 nan predictions from 16074 total
# ItemKNN with 500 neighbors, jaccard similarity and mode for cold start: RMSE = 1.3067704011344285
#
#
# Starting training on UserKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.556010 sec
# prediction_time:: 249.837700 sec
# 79 nan predictions from 16074 total
# UserKNN with 1 neighbors, cosine similarity and average for cold start: RMSE = 1.283369354081267
# 79 nan predictions from 16074 total
# UserKNN with 1 neighbors, cosine similarity and mode for cold start: RMSE = 1.2873951988152392
#
#
# Starting training on UserKNN with 10 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.200681 sec
# prediction_time:: 509.225108 sec
# 79 nan predictions from 16074 total
# UserKNN with 10 neighbors, cosine similarity and average for cold start: RMSE = 1.101274263299881
# 79 nan predictions from 16074 total
# UserKNN with 10 neighbors, cosine similarity and mode for cold start: RMSE = 1.105963155780633
#
#
# Starting training on UserKNN with 50 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.535235 sec
# prediction_time:: 720.772324 sec
# 79 nan predictions from 16074 total
# UserKNN with 50 neighbors, cosine similarity and average for cold start: RMSE = 1.0954789633387498
# 79 nan predictions from 16074 total
# UserKNN with 50 neighbors, cosine similarity and mode for cold start: RMSE = 1.100192554989945
#
#
# Starting training on UserKNN with 150 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.527089 sec
# prediction_time:: 743.390465 sec
# 79 nan predictions from 16074 total
# UserKNN with 150 neighbors, cosine similarity and average for cold start: RMSE = 1.0956395513542814
# 79 nan predictions from 16074 total
# UserKNN with 150 neighbors, cosine similarity and mode for cold start: RMSE = 1.1003524550930812
#
#
# Starting training on UserKNN with 300 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.222502 sec
# prediction_time:: 735.440122 sec
# 79 nan predictions from 16074 total
# UserKNN with 300 neighbors, cosine similarity and average for cold start: RMSE = 1.0956395513542814
# 79 nan predictions from 16074 total
# UserKNN with 300 neighbors, cosine similarity and mode for cold start: RMSE = 1.1003524550930812
#
#
# Starting training on UserKNN with 500 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.249319 sec
# prediction_time:: 720.390407 sec
# 79 nan predictions from 16074 total
# UserKNN with 500 neighbors, cosine similarity and average for cold start: RMSE = 1.0956395513542814
# 79 nan predictions from 16074 total
# UserKNN with 500 neighbors, cosine similarity and mode for cold start: RMSE = 1.1003524550930812
#
#
# Starting training on UserKNN with 1 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.287569 sec
# prediction_time:: 264.043689 sec
# 79 nan predictions from 16074 total
# UserKNN with 1 neighbors, hamming similarity and average for cold start: RMSE = 1.2316817827230166
# 79 nan predictions from 16074 total
# UserKNN with 1 neighbors, hamming similarity and mode for cold start: RMSE = 1.2358760102976791
#
#
# Starting training on UserKNN with 10 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.352068 sec
# prediction_time:: 657.426473 sec
# 79 nan predictions from 16074 total
# UserKNN with 10 neighbors, hamming similarity and average for cold start: RMSE = 1.0147557648127277
# 79 nan predictions from 16074 total
# UserKNN with 10 neighbors, hamming similarity and mode for cold start: RMSE = 1.0198425178223476
#
#
# Starting training on UserKNN with 50 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.264805 sec
# prediction_time:: 1054.118937 sec
# 79 nan predictions from 16074 total
# UserKNN with 50 neighbors, hamming similarity and average for cold start: RMSE = 0.9984313686473597
# 79 nan predictions from 16074 total
# UserKNN with 50 neighbors, hamming similarity and mode for cold start: RMSE = 1.0036008653028359
#
#
# Starting training on UserKNN with 150 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.318576 sec
# prediction_time:: 1116.967924 sec
# 79 nan predictions from 16074 total
# UserKNN with 150 neighbors, hamming similarity and average for cold start: RMSE = 0.9978294765842801
# 79 nan predictions from 16074 total
# UserKNN with 150 neighbors, hamming similarity and mode for cold start: RMSE = 1.0030020754106241
#
#
# Starting training on UserKNN with 300 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.456491 sec
# prediction_time:: 1148.309318 sec
# 79 nan predictions from 16074 total
# UserKNN with 300 neighbors, hamming similarity and average for cold start: RMSE = 0.9978294765842801
# 79 nan predictions from 16074 total
# UserKNN with 300 neighbors, hamming similarity and mode for cold start: RMSE = 1.0030020754106241
#
#
# Starting training on UserKNN with 500 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.612339 sec
# prediction_time:: 1115.311761 sec
# 79 nan predictions from 16074 total
# UserKNN with 500 neighbors, hamming similarity and average for cold start: RMSE = 0.9978294765842801
# 79 nan predictions from 16074 total
# UserKNN with 500 neighbors, hamming similarity and mode for cold start: RMSE = 1.0030020754106241
#
#
# Starting training on UserKNN with 1 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.112201 sec
# prediction_time:: 195.062501 sec
# 79 nan predictions from 16074 total
# UserKNN with 1 neighbors, jaccard similarity and average for cold start: RMSE = 1.308156685826905
# 79 nan predictions from 16074 total
# UserKNN with 1 neighbors, jaccard similarity and mode for cold start: RMSE = 1.3121064795248871
#
#
# Starting training on UserKNN with 10 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.195881 sec
# prediction_time:: 409.989029 sec
# 79 nan predictions from 16074 total
# UserKNN with 10 neighbors, jaccard similarity and average for cold start: RMSE = 1.1873241555676421
# 79 nan predictions from 16074 total
# UserKNN with 10 neighbors, jaccard similarity and mode for cold start: RMSE = 1.1916745148453813
#
#
# Starting training on UserKNN with 50 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.096338 sec
# prediction_time:: 642.809687 sec
# 79 nan predictions from 16074 total
# UserKNN with 50 neighbors, jaccard similarity and average for cold start: RMSE = 1.1869534779220028
# 79 nan predictions from 16074 total
# UserKNN with 50 neighbors, jaccard similarity and mode for cold start: RMSE = 1.1913051908258854
#
#
# Starting training on UserKNN with 150 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.373214 sec
# prediction_time:: 704.908767 sec
# 79 nan predictions from 16074 total
# UserKNN with 150 neighbors, jaccard similarity and average for cold start: RMSE = 1.1888172823685272
# 79 nan predictions from 16074 total
# UserKNN with 150 neighbors, jaccard similarity and mode for cold start: RMSE = 1.1931621976058628
#
#
# Starting training on UserKNN with 300 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.463571 sec
# prediction_time:: 700.086672 sec
# 79 nan predictions from 16074 total
# UserKNN with 300 neighbors, jaccard similarity and average for cold start: RMSE = 1.1888172823685272
# 79 nan predictions from 16074 total
# UserKNN with 300 neighbors, jaccard similarity and mode for cold start: RMSE = 1.1931621976058628
#
#
# Starting training on UserKNN with 500 neighbors and jaccard similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 7.559819 sec
# prediction_time:: 690.919266 sec
# 79 nan predictions from 16074 total
# UserKNN with 500 neighbors, jaccard similarity and average for cold start: RMSE = 1.1888172823685272
# 79 nan predictions from 16074 total
# UserKNN with 500 neighbors, jaccard similarity and mode for cold start: RMSE = 1.1931621976058628

# %% [markdown]
# ## Filtagem Baseada em Conteúdo

# %%
def generate_sim_file(movies_data, train, metric):
    sim_data = 1 - pd.DataFrame(pairwise_distances(movies_data, metric=metric))

    sim_data.index.name = "item_1"
    sim_data.reset_index(inplace=True)
    sim_data = sim_data.melt(id_vars=['item_1'], var_name="item_2", value_name="similarity")

    sim_data.item_1 = sim_data.item_1 + 1
    sim_data.item_2 = sim_data.item_2 + 1

    exists_in_train = sim_data.item_1.isin(train.movie_id) & sim_data.item_2.isin(train.movie_id)
    sim_data = sim_data[exists_in_train]

    sim_data.to_csv('similarity_data.dat', index=False, header=False, sep='\t')
    del sim_data

# %%
def fbc_predict(func, train, test, k_neighbors, similarity, train_file):
    func_name = func.__name__
    
    print(f"\n\nStarting training on {func_name} with {k_neighbors} neighbors and {similarity} similarity")

    train_output = f'train_outputs/{func_name}_{similarity}_{"default" if k_neighbors is None else k_neighbors}k.dat'
    result_output = f'result_outputs/results_{train_output}'

    func(train_file, output_file=train_output, k_neighbors=k_neighbors,
            similarity_file='similarity_data.dat', as_similar_first=True).compute()

    preds = pd.read_csv(train_output, sep='\t', names=['user_id', 'movie_id', 'rating'])
    preds.set_index(['user_id', 'movie_id'], inplace=True)

    results = test.join(preds, how='left').reset_index()
    return results

# %%
def fbc_run_tests(train, test, funcs, k_neighbors, similarities, cold_starts, content_data):
    global movies_data
    test_results_file = f'test_results_FBC_{content_data}.csv'

    real_ratings = test.reset_index().rating
    to_test = test.drop(columns=['rating'])

    for func in funcs:
        func_name = func.__name__
        for sim in similarities:
            generate_sim_file(movies_data, train, sim)

            for k in k_neighbors:
                results = fbc_predict(func, train, to_test, k, sim, 'train.dat')
                for cold in cold_starts:
                    results = cold_start(results, train, 'movie_id', 'user_id', cold)
                    results = cold_start(results, train, 'user_id', 'movie_id', cold)
                    
                    qtd_nan = results.rating.isna().sum()
                    print(f"{qtd_nan} nan predictions from {results.shape[0]} total")

                    predicted = results.rating

                    used = np.logical_and(~real_ratings.isna(), ~predicted.isna())
                    rmse = mean_squared_error(real_ratings[used], predicted[used], squared=False)

                    msg = f"{func_name} with {k} neighbors, {sim} similarity and {cold} for cold start: RMSE = {rmse}"
                    print(msg)

                    with open(test_results_file, 'a') as f:
                        data = f"{func_name},{k},{sim},{cold},{rmse}\n"
                        f.write(data)

    files.download(test_results_file)

# %% [markdown]
# ### FBC-kNN utilizando o gênero dos filmes

# %%
# Creating attribute dataframe
def generate_genre_movies_data():
    movies_data = pd.read_csv('competition/movies_data.csv')
    movies_data.set_index('movie_id', inplace=True)

    movies_data.genres = movies_data.genres.str.split("|")
    movie_genres = movies_data["genres"].explode().unique()

    for genre in movie_genres:
        movies_data[genre] = movies_data.apply(lambda x: genre in x['genres'], axis=1).astype(int)

    movies_data.drop(columns=['title', 'genres'], inplace=True)
    return movies_data

# %%
movies_data = generate_genre_movies_data()

funcs = [ItemAttributeKNN]
cold_starts = ['average', 'mode']
k_neighbors = [1, 10, 50, 150, 300, 500]
similarities = ['cosine', 'euclidean', 'manhattan']
fbc_run_tests(train, eval, funcs, k_neighbors, similarities, cold_starts, 'Genre_Metadata')
# Out:
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.763031 sec
# prediction_time:: 41.599294 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, cosine similarity and average for cold start: RMSE = 1.0036174719143627
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, cosine similarity and mode for cold start: RMSE = 1.0087603921989294
#
#
# Starting training on ItemAttributeKNN with 10 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.803148 sec
# prediction_time:: 53.062351 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, cosine similarity and average for cold start: RMSE = 1.0271107046315036
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, cosine similarity and mode for cold start: RMSE = 1.0321365696971427
#
#
# Starting training on ItemAttributeKNN with 50 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.908221 sec
# prediction_time:: 78.364198 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, cosine similarity and average for cold start: RMSE = 1.0832842680596801
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, cosine similarity and mode for cold start: RMSE = 1.08805069016253
#
#
# Starting training on ItemAttributeKNN with 150 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.649389 sec
# prediction_time:: 143.385048 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, cosine similarity and average for cold start: RMSE = 1.0908795785733976
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, cosine similarity and mode for cold start: RMSE = 1.0956129580677818
#
#
# Starting training on ItemAttributeKNN with 300 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.869710 sec
# prediction_time:: 215.621747 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, cosine similarity and average for cold start: RMSE = 1.077533823965065
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, cosine similarity and mode for cold start: RMSE = 1.0823255705776966
#
#
# Starting training on ItemAttributeKNN with 500 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.124760 sec
# prediction_time:: 367.750073 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, cosine similarity and average for cold start: RMSE = 1.0721180429845274
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, cosine similarity and mode for cold start: RMSE = 1.076933887028602
#
#
# Starting training on ItemAttributeKNN with 1 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.922132 sec
# prediction_time:: 44.115721 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, euclidean similarity and average for cold start: RMSE = 1.00395726077312
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, euclidean similarity and mode for cold start: RMSE = 1.009098449308405
#
#
# Starting training on ItemAttributeKNN with 10 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.993174 sec
# prediction_time:: 50.068248 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, euclidean similarity and average for cold start: RMSE = 1.0323981150705652
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, euclidean similarity and mode for cold start: RMSE = 1.0373983646308766
#
#
# Starting training on ItemAttributeKNN with 50 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.072647 sec
# prediction_time:: 77.777386 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, euclidean similarity and average for cold start: RMSE = 1.1055943854124426
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, euclidean similarity and mode for cold start: RMSE = 1.1102650332209323
#
#
# Starting training on ItemAttributeKNN with 150 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.123590 sec
# prediction_time:: 151.801727 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, euclidean similarity and average for cold start: RMSE = 1.1599540530103745
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, euclidean similarity and mode for cold start: RMSE = 1.1644066746771746
#
#
# Starting training on ItemAttributeKNN with 300 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.679811 sec
# /usr/local/lib/python3.7/dist-packages/caserec/recommenders/rating_prediction/itemknn.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   rui = self.bui[user][item_j] + (rui / sim_sum)
# prediction_time:: 207.303226 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, euclidean similarity and average for cold start: RMSE = 1.1802890592822755
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, euclidean similarity and mode for cold start: RMSE = 1.1846652533095583
#
#
# Starting training on ItemAttributeKNN with 500 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.751205 sec
# /usr/local/lib/python3.7/dist-packages/caserec/recommenders/rating_prediction/itemknn.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   rui = self.bui[user][item_j] + (rui / sim_sum)
# prediction_time:: 360.810363 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, euclidean similarity and average for cold start: RMSE = 1.1895144374948798
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, euclidean similarity and mode for cold start: RMSE = 1.1938568155127822
#
#
# Starting training on ItemAttributeKNN with 1 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.254017 sec
# prediction_time:: 42.142978 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, manhattan similarity and average for cold start: RMSE = 1.00395726077312
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, manhattan similarity and mode for cold start: RMSE = 1.009098449308405
#
#
# Starting training on ItemAttributeKNN with 10 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.032493 sec
# /usr/local/lib/python3.7/dist-packages/caserec/recommenders/rating_prediction/itemknn.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   rui = self.bui[user][item_j] + (rui / sim_sum)
# prediction_time:: 49.870428 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, manhattan similarity and average for cold start: RMSE = 1.0323979451748848
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, manhattan similarity and mode for cold start: RMSE = 1.0373981955540919
#
#
# Starting training on ItemAttributeKNN with 50 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.051651 sec
# /usr/local/lib/python3.7/dist-packages/caserec/recommenders/rating_prediction/itemknn.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   rui = self.bui[user][item_j] + (rui / sim_sum)
# prediction_time:: 76.872595 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, manhattan similarity and average for cold start: RMSE = 1.105566005699164
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, manhattan similarity and mode for cold start: RMSE = 1.1102367728980902
#
#
# Starting training on ItemAttributeKNN with 150 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.174960 sec
# /usr/local/lib/python3.7/dist-packages/caserec/recommenders/rating_prediction/itemknn.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   rui = self.bui[user][item_j] + (rui / sim_sum)
# prediction_time:: 145.633842 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, manhattan similarity and average for cold start: RMSE = 1.1657556692823965
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, manhattan similarity and mode for cold start: RMSE = 1.170186215694583
#
#
# Starting training on ItemAttributeKNN with 300 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 8.875921 sec
# /usr/local/lib/python3.7/dist-packages/caserec/recommenders/rating_prediction/itemknn.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   rui = self.bui[user][item_j] + (rui / sim_sum)
# prediction_time:: 203.333588 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, manhattan similarity and average for cold start: RMSE = 1.1866005456336994
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, manhattan similarity and mode for cold start: RMSE = 1.190953548143568
#
#
# Starting training on ItemAttributeKNN with 500 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.845693 sec
# /usr/local/lib/python3.7/dist-packages/caserec/recommenders/rating_prediction/itemknn.py:204: RuntimeWarning: divide by zero encountered in double_scalars
#   rui = self.bui[user][item_j] + (rui / sim_sum)
# prediction_time:: 354.622378 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, manhattan similarity and average for cold start: RMSE = 1.1802875874682393
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, manhattan similarity and mode for cold start: RMSE = 1.1846637869324603

# %% [markdown]
# ### FBC-kNN utilizando reviews dos filmes

# %%
def generate_review_movies_data():
    nltk.download('punkt')
    nltk.download('stopwords')

    stop = set(stopwords.words('english'))
    stemmer = SnowballStemmer("english")

    vectorizer = TfidfVectorizer()

    # Reading
    movies_data = pd.read_csv('competition/movie_reviews.csv')
    movies_data.set_index('movie_id', inplace=True)

    # Normalizing
    movies_data.text = movies_data.text.str.replace('[^\w\s]','', regex=True).str.lower()

    # Tokenizing
    movies_data.text = movies_data.text.apply(word_tokenize)

    # Groups every movies reviews into one big string
    movies_data = movies_data.groupby('movie_id').sum()

    # Stemming and removing stopwords
    movies_data.text = movies_data.text.apply(lambda x: ' '.join([stemmer.stem(item) for item in x if item not in stop]))
    indexes = movies_data.index

    tfidf = vectorizer.fit_transform(movies_data.text)
    movies_data = pd.DataFrame(tfidf.toarray())
    movies_data.index = indexes

    return movies_data

# %%
movies_data = generate_review_movies_data()

funcs = [ItemAttributeKNN]
cold_starts = ['average', 'mode']
k_neighbors = [1, 10, 50, 150, 300, 500]
similarities = ['cosine', 'euclidean', 'manhattan']
fbc_run_tests(train, eval, funcs, k_neighbors, similarities, cold_starts, 'Review_Metadata')
# Out:
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 11.368190 sec
# prediction_time:: 48.798820 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, cosine similarity and average for cold start: RMSE = 1.0048112859605716
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, cosine similarity and mode for cold start: RMSE = 1.0099481270497503
#
#
# Starting training on ItemAttributeKNN with 10 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 11.224757 sec
# prediction_time:: 56.443631 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, cosine similarity and average for cold start: RMSE = 1.0373434262061356
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, cosine similarity and mode for cold start: RMSE = 1.042319952236666
#
#
# Starting training on ItemAttributeKNN with 50 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.238025 sec
# prediction_time:: 84.815914 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, cosine similarity and average for cold start: RMSE = 1.1081744758418812
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, cosine similarity and mode for cold start: RMSE = 1.1128342948727763
#
#
# Starting training on ItemAttributeKNN with 150 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.818095 sec
# prediction_time:: 144.029729 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, cosine similarity and average for cold start: RMSE = 1.1501871324363029
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, cosine similarity and mode for cold start: RMSE = 1.154677417532536
#
#
# Starting training on ItemAttributeKNN with 300 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.554842 sec
# prediction_time:: 207.246191 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, cosine similarity and average for cold start: RMSE = 1.1634126948162273
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, cosine similarity and mode for cold start: RMSE = 1.1678521299364562
#
#
# Starting training on ItemAttributeKNN with 500 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.479905 sec
# prediction_time:: 343.845171 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, cosine similarity and average for cold start: RMSE = 1.160075156523063
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, cosine similarity and mode for cold start: RMSE = 1.1645273151453213
#
#
# Starting training on ItemAttributeKNN with 1 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.315999 sec
# prediction_time:: 47.151786 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, euclidean similarity and average for cold start: RMSE = 1.0057928749434257
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, euclidean similarity and mode for cold start: RMSE = 1.0109247282683922
#
#
# Starting training on ItemAttributeKNN with 10 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.158273 sec
# prediction_time:: 49.943823 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, euclidean similarity and average for cold start: RMSE = 1.0537077169171294
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, euclidean similarity and mode for cold start: RMSE = 1.0586073170105477
#
#
# Starting training on ItemAttributeKNN with 50 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.314951 sec
# prediction_time:: 67.027260 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, euclidean similarity and average for cold start: RMSE = 1.1356014211215728
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, euclidean similarity and mode for cold start: RMSE = 1.1401491510284507
#
#
# Starting training on ItemAttributeKNN with 150 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.455091 sec
# prediction_time:: 98.626513 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, euclidean similarity and average for cold start: RMSE = 1.2395727074702734
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, euclidean similarity and mode for cold start: RMSE = 1.243740325004679
#
#
# Starting training on ItemAttributeKNN with 300 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.227915 sec
# prediction_time:: 142.328969 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, euclidean similarity and average for cold start: RMSE = 1.3010260368263113
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, euclidean similarity and mode for cold start: RMSE = 1.3049974128087534
#
#
# Starting training on ItemAttributeKNN with 500 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.972149 sec
# prediction_time:: 205.769376 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, euclidean similarity and average for cold start: RMSE = 1.3347954025555375
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, euclidean similarity and mode for cold start: RMSE = 1.3386665998750251
#
#
# Starting training on ItemAttributeKNN with 1 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 11.806666 sec
# prediction_time:: 49.322568 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, manhattan similarity and average for cold start: RMSE = 1.0055690650461724
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 1 neighbors, manhattan similarity and mode for cold start: RMSE = 1.010702054769552
#
#
# Starting training on ItemAttributeKNN with 10 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.814824 sec
# prediction_time:: 52.503919 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, manhattan similarity and average for cold start: RMSE = 1.0553055309990733
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 10 neighbors, manhattan similarity and mode for cold start: RMSE = 1.0601977469768538
#
#
# Starting training on ItemAttributeKNN with 50 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.930918 sec
# prediction_time:: 69.492685 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, manhattan similarity and average for cold start: RMSE = 1.1360200366043247
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 50 neighbors, manhattan similarity and mode for cold start: RMSE = 1.1405660973850014
#
#
# Starting training on ItemAttributeKNN with 150 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.439733 sec
# prediction_time:: 96.541202 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, manhattan similarity and average for cold start: RMSE = 1.24069272098425
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 150 neighbors, manhattan similarity and mode for cold start: RMSE = 1.2448565888651042
#
#
# Starting training on ItemAttributeKNN with 300 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.116447 sec
# prediction_time:: 138.890395 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, manhattan similarity and average for cold start: RMSE = 1.3017447375244537
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 300 neighbors, manhattan similarity and mode for cold start: RMSE = 1.3057139275546423
#
#
# Starting training on ItemAttributeKNN with 500 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 10.146786 sec
# prediction_time:: 210.721805 sec
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, manhattan similarity and average for cold start: RMSE = 1.3355954704085962
# 79 nan predictions from 16074 total
# ItemAttributeKNN with 500 neighbors, manhattan similarity and mode for cold start: RMSE = 1.3394643554471766

# %% [markdown]
# ## Fatoração de Matrizes

# %% [markdown]
# ### SVD da Algebra Linear

# %%
def svd_predict(func, train, test, factors, train_file, test_file):
    func_name = func.__name__
    
    print(f"\n\nStarting training on {func_name} with {factors} factors")

    train_output = f'train_outputs/{func_name}_{factors}_factors.dat'
    result_output = f'result_outputs/results_{train_output}'

    func(train_file, test_file, output_file=train_output, factors=factors).compute()

    preds = pd.read_csv(train_output, sep='\t', names=['user_id', 'movie_id', 'rating'])
    preds.set_index(['user_id', 'movie_id'], inplace=True)

    results = test.join(preds, how='left').reset_index()
    return results

# %%
def svd_run_tests(train, test, func, num_factors):
    test_results_file = f'test_results_SVD.csv'

    real_ratings = test.reset_index().rating
    to_test = test.drop(columns=['rating'])

    func_name = func.__name__
    for factors in num_factors:

        results = svd_predict(func, train, to_test, factors, 'train.dat', 'test.dat')
        
        qtd_nan = results.rating.isna().sum()
        print(f"{qtd_nan} nan predictions from {results.shape[0]} total")

        predicted = results.rating

        used = np.logical_and(~real_ratings.isna(), ~predicted.isna())
        rmse = mean_squared_error(real_ratings[used], predicted[used], squared=False)

        msg = f"{func_name} with {factors} factors: RMSE = {rmse}"
        print(msg)

        with open(test_results_file, 'a') as f:
            data = f"{func_name},{factors},{rmse}\n"
            f.write(data)

    files.download(test_results_file)

# %%
num_factors = [1, 2, 5, 10, 20, 30, 40, 50, 75, 100, 125, 150, 200, 250, 500]
svd_run_tests(train, eval, SVD, num_factors)
# Out:
# Starting training on SVD with 1 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 0.570385 sec
# prediction_time:: 0.069045 sec
#
#
# Eval:: MAE: 0.913083 RMSE: 1.107041
# 0 nan predictions from 16074 total
# SVD with 1 factors: RMSE = 1.107040927088219
#
#
# Starting training on SVD with 2 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 1.393595 sec
# prediction_time:: 0.046584 sec
#
#
# Eval:: MAE: 0.913358 RMSE: 1.107462
# 0 nan predictions from 16074 total
# SVD with 2 factors: RMSE = 1.107461866767029
#
#
# Starting training on SVD with 5 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 2.725790 sec
# prediction_time:: 0.051108 sec
#
#
# Eval:: MAE: 0.912888 RMSE: 1.107909
# 0 nan predictions from 16074 total
# SVD with 5 factors: RMSE = 1.1079086720971263
#
#
# Starting training on SVD with 10 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 3.275762 sec
# prediction_time:: 0.046106 sec
#
#
# Eval:: MAE: 0.915538 RMSE: 1.111466
# 0 nan predictions from 16074 total
# SVD with 10 factors: RMSE = 1.111466283724908
#
#
# Starting training on SVD with 20 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 3.912461 sec
# prediction_time:: 0.045306 sec
#
#
# Eval:: MAE: 0.918928 RMSE: 1.116066
# 0 nan predictions from 16074 total
# SVD with 20 factors: RMSE = 1.1160661105485001
#
#
# Starting training on SVD with 30 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 4.492720 sec
# prediction_time:: 0.047513 sec
#
#
# Eval:: MAE: 0.920374 RMSE: 1.117794
# 0 nan predictions from 16074 total
# SVD with 30 factors: RMSE = 1.1177937327788567
#
#
# Starting training on SVD with 40 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 5.239083 sec
# prediction_time:: 0.050719 sec
#
#
# Eval:: MAE: 0.921549 RMSE: 1.11979
# 0 nan predictions from 16074 total
# SVD with 40 factors: RMSE = 1.1197899983134683
#
#
# Starting training on SVD with 50 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 6.287349 sec
# prediction_time:: 0.047046 sec
#
#
# Eval:: MAE: 0.92253 RMSE: 1.121241
# 0 nan predictions from 16074 total
# SVD with 50 factors: RMSE = 1.12124126378325
#
#
# Starting training on SVD with 75 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 7.980409 sec
# prediction_time:: 0.045055 sec
#
#
# Eval:: MAE: 0.92703 RMSE: 1.125983
# 0 nan predictions from 16074 total
# SVD with 75 factors: RMSE = 1.1259828024328666
#
#
# Starting training on SVD with 100 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 9.313580 sec
# prediction_time:: 0.051280 sec
#
#
# Eval:: MAE: 0.92911 RMSE: 1.128319
# 0 nan predictions from 16074 total
# SVD with 100 factors: RMSE = 1.1283188899770387
#
#
# Starting training on SVD with 125 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 11.278471 sec
# prediction_time:: 0.043762 sec
#
#
# Eval:: MAE: 0.930685 RMSE: 1.129975
# 0 nan predictions from 16074 total
# SVD with 125 factors: RMSE = 1.1299745374651886
#
#
# Starting training on SVD with 150 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 11.288976 sec
# prediction_time:: 0.048047 sec
#
#
# Eval:: MAE: 0.931112 RMSE: 1.129677
# 0 nan predictions from 16074 total
# SVD with 150 factors: RMSE = 1.1296773263839102
#
#
# Starting training on SVD with 200 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 15.591370 sec
# prediction_time:: 0.044223 sec
#
#
# Eval:: MAE: 0.930054 RMSE: 1.128318
# 0 nan predictions from 16074 total
# SVD with 200 factors: RMSE = 1.1283177338892412
#
#
# Starting training on SVD with 250 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 20.822352 sec
# prediction_time:: 0.044967 sec
#
#
# Eval:: MAE: 0.932193 RMSE: 1.12918
# 0 nan predictions from 16074 total
# SVD with 250 factors: RMSE = 1.1291795724969662
#
#
# Starting training on SVD with 500 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 39.326543 sec
# prediction_time:: 0.043624 sec
#
#
# Eval:: MAE: 0.933399 RMSE: 1.123338
# 0 nan predictions from 16074 total
# SVD with 500 factors: RMSE = 1.1233384885732849

# %% [markdown]
# ### Gradiente Descendente Estocastico

# %%
def sgd_predict(func, train, test, factors, epochs, delta, learn_rate, train_file, test_file):
    func_name = func.__name__
    
    print(f"\n\nStarting training on {func_name} with {factors} factors, {epochs} epochs, {delta} delta, {learn_rate} learn_rate")

    train_output = f'train_outputs/{func_name}_{factors}_{epochs}epochs_{delta}delta_{learn_rate}learnrate.dat'
    result_output = f'result_outputs/results_{train_output}'

    func(train_file, test_file, output_file=train_output, factors=factors).compute()

    preds = pd.read_csv(train_output, sep='\t', names=['user_id', 'movie_id', 'rating'])
    preds.set_index(['user_id', 'movie_id'], inplace=True)

    results = test.join(preds, how='left').reset_index()
    return results

# %%
def sgd_run_tests(train, test, func, num_factors, num_epochs, deltas, learn_rates):
    test_results_file = f'test_results_SGD.csv'

    real_ratings = test.reset_index().rating
    to_test = test.drop(columns=['rating'])

    func_name = func.__name__
    for factors in num_factors:
        for epochs in num_epochs:
            for delta in deltas:
                for learn_rate in learn_rates:

                    results = sgd_predict(func, train, to_test, factors, epochs, delta, learn_rate, 'train.dat', 'test.dat')
                    
                    qtd_nan = results.rating.isna().sum()
                    print(f"{qtd_nan} nan predictions from {results.shape[0]} total")

                    predicted = results.rating

                    used = np.logical_and(~real_ratings.isna(), ~predicted.isna())
                    rmse = mean_squared_error(real_ratings[used], predicted[used], squared=False)

                    msg = f"{func_name} with {factors} factors: RMSE = {rmse}"
                    print(msg)

                    with open(test_results_file, 'a') as f:
                        data = f"{func_name},{factors},{epochs},{delta},{learn_rate},{rmse}\n"
                        f.write(data)

    files.download(test_results_file)

# %%
deltas = [.005, .01, .05, .1, .2, .5]
num_epochs = [5, 10, 15, 20, 30, 50, 100] 
learn_rates = [.001, .005, .01, .03, .05]
num_factors = [1, 2, 5, 10, 30, 50, 100, 150, 200, 300, 500]

sgd_run_tests(train, eval, MatrixFactorization, num_factors, num_epochs, deltas, learn_rates)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# Eval:: MAE: 0.909516 RMSE: 1.179692
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.179692251214156
#
#
# Starting training on MatrixFactorization with 300 factors, 15 epochs, 0.5 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.162014 sec
# prediction_time:: 0.071169 sec
#
#
# Eval:: MAE: 0.909658 RMSE: 1.179594
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1795940428070122
#
#
# Starting training on MatrixFactorization with 300 factors, 15 epochs, 0.5 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.623559 sec
# prediction_time:: 0.079297 sec
#
#
# Eval:: MAE: 0.908648 RMSE: 1.179587
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1795874988519428
#
#
# Starting training on MatrixFactorization with 300 factors, 15 epochs, 0.5 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.100872 sec
# prediction_time:: 0.077918 sec
#
#
# Eval:: MAE: 0.910151 RMSE: 1.180266
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1802662687967018
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.005 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.040589 sec
# prediction_time:: 0.076963 sec
#
#
# Eval:: MAE: 0.910702 RMSE: 1.183072
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1830718228963626
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.005 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.073482 sec
# prediction_time:: 0.078645 sec
#
#
# Eval:: MAE: 0.910758 RMSE: 1.183105
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1831048657551573
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.005 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.309795 sec
# prediction_time:: 0.083860 sec
#
#
# Eval:: MAE: 0.908488 RMSE: 1.180033
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1800332045142659
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.005 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.021426 sec
# prediction_time:: 0.071991 sec
#
#
# Eval:: MAE: 0.908515 RMSE: 1.178074
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1780735124155948
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.005 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.086994 sec
# prediction_time:: 0.073391 sec
#
#
# Eval:: MAE: 0.912412 RMSE: 1.182561
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1825611786129555
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.01 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.244431 sec
# prediction_time:: 0.079594 sec
#
#
# Eval:: MAE: 0.908756 RMSE: 1.180544
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1805442815483285
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.01 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.622546 sec
# prediction_time:: 0.075865 sec
#
#
# Eval:: MAE: 0.912604 RMSE: 1.182868
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1828675636146713
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.01 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.050991 sec
# prediction_time:: 0.085028 sec
#
#
# Eval:: MAE: 0.908655 RMSE: 1.18113
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1811295393152568
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.01 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.488894 sec
# prediction_time:: 0.088714 sec
#
#
# Eval:: MAE: 0.911515 RMSE: 1.183135
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1831354348173866
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.01 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.217944 sec
# prediction_time:: 0.073978 sec
#
#
# Eval:: MAE: 0.911025 RMSE: 1.180909
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1809091963331224
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.05 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.818704 sec
# prediction_time:: 0.067859 sec
#
#
# Eval:: MAE: 0.909896 RMSE: 1.180643
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1806431923930407
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.05 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.893516 sec
# prediction_time:: 0.076827 sec
#
#
# Eval:: MAE: 0.908987 RMSE: 1.17987
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1798698238118683
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.05 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.974950 sec
# prediction_time:: 0.069898 sec
#
#
# Eval:: MAE: 0.912491 RMSE: 1.181962
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1819616306829128
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.05 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.432162 sec
# prediction_time:: 0.073404 sec
#
#
# Eval:: MAE: 0.90727 RMSE: 1.178935
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.178934729996845
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.05 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.059592 sec
# prediction_time:: 0.079548 sec
#
#
# Eval:: MAE: 0.90783 RMSE: 1.179264
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1792639489395582
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.1 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.285435 sec
# prediction_time:: 0.074234 sec
#
#
# Eval:: MAE: 0.908116 RMSE: 1.179143
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.179142651662875
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.1 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.173194 sec
# prediction_time:: 0.068398 sec
#
#
# Eval:: MAE: 0.908973 RMSE: 1.181202
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1812019536294778
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.1 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.820070 sec
# prediction_time:: 0.078315 sec
#
#
# Eval:: MAE: 0.90927 RMSE: 1.180643
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1806433672221226
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.1 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.693140 sec
# prediction_time:: 0.083121 sec
#
#
# Eval:: MAE: 0.910321 RMSE: 1.181807
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1818066697833842
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.1 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.205951 sec
# prediction_time:: 0.072453 sec
#
#
# Eval:: MAE: 0.91 RMSE: 1.182071
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.182070962551665
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.2 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.230117 sec
# prediction_time:: 0.071823 sec
#
#
# Eval:: MAE: 0.912913 RMSE: 1.184287
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1842874213999108
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.2 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.787534 sec
# prediction_time:: 0.075499 sec
#
#
# Eval:: MAE: 0.909421 RMSE: 1.179829
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.17982887330501
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.2 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.574148 sec
# prediction_time:: 0.073856 sec
#
#
# Eval:: MAE: 0.908542 RMSE: 1.181001
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1810007107477256
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.2 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.105582 sec
# prediction_time:: 0.080728 sec
#
#
# Eval:: MAE: 0.908126 RMSE: 1.177332
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.177332303333741
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.2 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.204820 sec
# prediction_time:: 0.070786 sec
#
#
# Eval:: MAE: 0.909473 RMSE: 1.18007
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.180070344188583
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.5 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.122478 sec
# prediction_time:: 0.073704 sec
#
#
# Eval:: MAE: 0.90993 RMSE: 1.18045
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1804498975847593
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.5 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.885135 sec
# prediction_time:: 0.086894 sec
#
#
# Eval:: MAE: 0.909386 RMSE: 1.180546
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1805456678197626
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.5 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.075179 sec
# prediction_time:: 0.070208 sec
#
#
# Eval:: MAE: 0.914417 RMSE: 1.183355
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1833553095614757
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.5 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.391551 sec
# prediction_time:: 0.082156 sec
#
#
# Eval:: MAE: 0.909257 RMSE: 1.178751
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1787507520360883
#
#
# Starting training on MatrixFactorization with 300 factors, 20 epochs, 0.5 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.065840 sec
# prediction_time:: 0.072127 sec
#
#
# Eval:: MAE: 0.910823 RMSE: 1.180458
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.180458063532213
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.005 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.548463 sec
# prediction_time:: 0.065867 sec
#
#
# Eval:: MAE: 0.907691 RMSE: 1.179732
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1797321215210048
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.005 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.321413 sec
# prediction_time:: 0.068984 sec
#
#
# Eval:: MAE: 0.909845 RMSE: 1.181703
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.18170309599773
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.005 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.230430 sec
# prediction_time:: 0.073828 sec
#
#
# Eval:: MAE: 0.909429 RMSE: 1.179239
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1792387254688923
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.005 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.853636 sec
# prediction_time:: 0.077248 sec
#
#
# Eval:: MAE: 0.910898 RMSE: 1.181064
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1810638676663712
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.005 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.784810 sec
# prediction_time:: 0.068738 sec
#
#
# Eval:: MAE: 0.910613 RMSE: 1.179775
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1797746036405035
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.01 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.869092 sec
# prediction_time:: 0.081185 sec
#
#
# Eval:: MAE: 0.915071 RMSE: 1.184762
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1847618468234362
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.01 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.890566 sec
# prediction_time:: 0.070434 sec
#
#
# Eval:: MAE: 0.909821 RMSE: 1.179399
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1793992768896178
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.01 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.228025 sec
# prediction_time:: 0.067972 sec
#
#
# Eval:: MAE: 0.908336 RMSE: 1.178196
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1781957533268874
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.01 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.174281 sec
# prediction_time:: 0.067266 sec
#
#
# Eval:: MAE: 0.907153 RMSE: 1.178273
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1782734060484885
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.01 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.085064 sec
# prediction_time:: 0.079776 sec
#
#
# Eval:: MAE: 0.914463 RMSE: 1.183284
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1832837986077
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.05 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.974962 sec
# prediction_time:: 0.067944 sec
#
#
# Eval:: MAE: 0.91384 RMSE: 1.185966
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1859663253980917
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.05 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.270656 sec
# prediction_time:: 0.077633 sec
#
#
# Eval:: MAE: 0.911891 RMSE: 1.18334
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1833403535621543
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.05 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.590909 sec
# prediction_time:: 0.091396 sec
#
#
# Eval:: MAE: 0.907804 RMSE: 1.180016
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1800155758132072
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.05 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.884126 sec
# prediction_time:: 0.076046 sec
#
#
# Eval:: MAE: 0.910697 RMSE: 1.183837
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.183836763471224
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.05 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.234755 sec
# prediction_time:: 0.080399 sec
#
#
# Eval:: MAE: 0.908987 RMSE: 1.179639
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1796390073531022
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.1 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.180859 sec
# prediction_time:: 0.066299 sec
#
#
# Eval:: MAE: 0.91217 RMSE: 1.183103
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1831025308011442
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.1 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.818115 sec
# prediction_time:: 0.067806 sec
#
#
# Eval:: MAE: 0.911461 RMSE: 1.180653
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1806532986483471
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.1 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.537561 sec
# prediction_time:: 0.070006 sec
#
#
# Eval:: MAE: 0.907834 RMSE: 1.179014
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1790135518978146
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.1 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.868967 sec
# prediction_time:: 0.076934 sec
#
#
# Eval:: MAE: 0.913361 RMSE: 1.18315
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.183149916934036
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.1 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.978247 sec
# prediction_time:: 0.073776 sec
#
#
# Eval:: MAE: 0.90945 RMSE: 1.181527
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1815268693981382
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.2 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.475664 sec
# prediction_time:: 0.082808 sec
#
#
# Eval:: MAE: 0.908297 RMSE: 1.179512
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1795116475342902
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.2 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.060059 sec
# prediction_time:: 0.067878 sec
#
#
# Eval:: MAE: 0.913456 RMSE: 1.183543
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.183542923374517
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.2 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.759276 sec
# prediction_time:: 0.075859 sec
#
#
# Eval:: MAE: 0.913824 RMSE: 1.184466
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.18446627434455
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.2 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.891846 sec
# prediction_time:: 0.074357 sec
#
#
# Eval:: MAE: 0.909801 RMSE: 1.180122
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1801222477502586
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.2 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.512083 sec
# prediction_time:: 0.070292 sec
#
#
# Eval:: MAE: 0.909172 RMSE: 1.180427
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1804274882579442
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.5 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.237255 sec
# prediction_time:: 0.087622 sec
#
#
# Eval:: MAE: 0.910531 RMSE: 1.182187
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1821867393301577
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.5 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.296021 sec
# prediction_time:: 0.077738 sec
#
#
# Eval:: MAE: 0.907973 RMSE: 1.177422
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.177421696506486
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.5 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.817605 sec
# prediction_time:: 0.071485 sec
#
#
# Eval:: MAE: 0.912345 RMSE: 1.182267
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.182266871697573
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.5 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.847500 sec
# prediction_time:: 0.074968 sec
#
#
# Eval:: MAE: 0.910676 RMSE: 1.179525
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1795253568155752
#
#
# Starting training on MatrixFactorization with 300 factors, 30 epochs, 0.5 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.196135 sec
# prediction_time:: 0.074949 sec
#
#
# Eval:: MAE: 0.911573 RMSE: 1.183251
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1832508191881528
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.005 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.595056 sec
# prediction_time:: 0.076216 sec
#
#
# Eval:: MAE: 0.910881 RMSE: 1.181037
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1810366719415206
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.005 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.852611 sec
# prediction_time:: 0.074842 sec
#
#
# Eval:: MAE: 0.909176 RMSE: 1.182196
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1821955170897864
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.005 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.799557 sec
# prediction_time:: 0.078528 sec
#
#
# Eval:: MAE: 0.912807 RMSE: 1.182162
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1821616038117615
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.005 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.588006 sec
# prediction_time:: 0.067007 sec
#
#
# Eval:: MAE: 0.911761 RMSE: 1.182068
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1820679867289623
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.005 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.781860 sec
# prediction_time:: 0.067375 sec
#
#
# Eval:: MAE: 0.907099 RMSE: 1.179502
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1795021011967959
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.01 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.865052 sec
# prediction_time:: 0.075171 sec
#
#
# Eval:: MAE: 0.908874 RMSE: 1.18052
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1805204702966656
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.01 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.094365 sec
# prediction_time:: 0.076414 sec
#
#
# Eval:: MAE: 0.908408 RMSE: 1.179701
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1797005074942288
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.01 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.961281 sec
# prediction_time:: 0.070550 sec
#
#
# Eval:: MAE: 0.908202 RMSE: 1.180349
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1803485770417461
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.01 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.062228 sec
# prediction_time:: 0.071064 sec
#
#
# Eval:: MAE: 0.914882 RMSE: 1.184715
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1847152407618642
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.01 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.727160 sec
# prediction_time:: 0.076150 sec
#
#
# Eval:: MAE: 0.912778 RMSE: 1.182146
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1821458987322209
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.05 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.816837 sec
# prediction_time:: 0.073803 sec
#
#
# Eval:: MAE: 0.9092 RMSE: 1.179874
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1798735808417518
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.05 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.214099 sec
# prediction_time:: 0.076503 sec
#
#
# Eval:: MAE: 0.908435 RMSE: 1.178552
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.178552198290567
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.05 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.371988 sec
# prediction_time:: 0.070511 sec
#
#
# Eval:: MAE: 0.907019 RMSE: 1.181045
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1810448137418061
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.05 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.044520 sec
# prediction_time:: 0.079393 sec
#
#
# Eval:: MAE: 0.909417 RMSE: 1.178671
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1786710187537497
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.05 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.247678 sec
# prediction_time:: 0.066452 sec
#
#
# Eval:: MAE: 0.912555 RMSE: 1.184266
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1842662103812602
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.1 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.168781 sec
# prediction_time:: 0.074333 sec
#
#
# Eval:: MAE: 0.909986 RMSE: 1.180501
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.180501097695802
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.1 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.690292 sec
# prediction_time:: 0.088272 sec
#
#
# Eval:: MAE: 0.912057 RMSE: 1.184967
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1849665953620618
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.1 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.118311 sec
# prediction_time:: 0.074096 sec
#
#
# Eval:: MAE: 0.911732 RMSE: 1.182997
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1829965846028712
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.1 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.899534 sec
# prediction_time:: 0.077273 sec
#
#
# Eval:: MAE: 0.91029 RMSE: 1.182857
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1828569586222053
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.1 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.841570 sec
# prediction_time:: 0.076739 sec
#
#
# Eval:: MAE: 0.912079 RMSE: 1.184284
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1842842667832902
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.2 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.926199 sec
# prediction_time:: 0.069067 sec
#
#
# Eval:: MAE: 0.913548 RMSE: 1.183735
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1837345535018005
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.2 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.101463 sec
# prediction_time:: 0.075336 sec
#
#
# Eval:: MAE: 0.909079 RMSE: 1.179079
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.179079029868324
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.2 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.977643 sec
# prediction_time:: 0.066539 sec
#
#
# Eval:: MAE: 0.913907 RMSE: 1.186064
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1860641322762449
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.2 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.141720 sec
# prediction_time:: 0.076596 sec
#
#
# Eval:: MAE: 0.90909 RMSE: 1.181483
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.181483210726506
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.2 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.563457 sec
# prediction_time:: 0.081103 sec
#
#
# Eval:: MAE: 0.908325 RMSE: 1.179118
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1791175165663055
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.5 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 21.862928 sec
# prediction_time:: 0.090044 sec
#
#
# Eval:: MAE: 0.911757 RMSE: 1.18413
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1841304252073348
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.5 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.272415 sec
# prediction_time:: 0.072959 sec
#
#
# Eval:: MAE: 0.912242 RMSE: 1.184124
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1841244876357149
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.5 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.398176 sec
# prediction_time:: 0.070210 sec
#
#
# Eval:: MAE: 0.907851 RMSE: 1.179287
# 0 nan predictions from 16074 total
# MatrixFactorization with 300 factors: RMSE = 1.1792867953141768
#
#
# Starting training on MatrixFactorization with 300 factors, 50 epochs, 0.5 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 22.080890 sec
# prediction_time:: 0.072148 sec
#
#
# Eval:: MAE: 0.911425 RMSE: 1.180966
# ...
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.850980 sec
# prediction_time:: 0.080124 sec
#
#
# Eval:: MAE: 0.964552 RMSE: 1.255001
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2550006449123372
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.005 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.448572 sec
# prediction_time:: 0.089149 sec
#
#
# Eval:: MAE: 0.958 RMSE: 1.25089
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2508895098746604
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.005 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.712925 sec
# prediction_time:: 0.081206 sec
#
#
# Eval:: MAE: 0.958812 RMSE: 1.249246
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2492464952778164
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.005 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 18.079477 sec
# prediction_time:: 0.077387 sec
#
#
# Eval:: MAE: 0.963498 RMSE: 1.253288
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2532875321868286
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.005 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.874649 sec
# prediction_time:: 0.082075 sec
#
#
# Eval:: MAE: 0.959658 RMSE: 1.251588
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2515883972876465
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.005 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.998615 sec
# prediction_time:: 0.080449 sec
#
#
# Eval:: MAE: 0.959437 RMSE: 1.250975
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2509747148625263
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.01 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.640692 sec
# prediction_time:: 0.079113 sec
#
#
# Eval:: MAE: 0.95822 RMSE: 1.251089
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2510889597565762
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.01 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 18.455921 sec
# prediction_time:: 0.076254 sec
#
#
# Eval:: MAE: 0.961806 RMSE: 1.252659
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2526589455964676
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.01 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 18.077614 sec
# prediction_time:: 0.080243 sec
#
#
# Eval:: MAE: 0.959002 RMSE: 1.251364
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2513644938128645
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.01 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.468966 sec
# prediction_time:: 0.092171 sec
#
#
# Eval:: MAE: 0.958531 RMSE: 1.248632
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2486321592411755
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.01 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.613965 sec
# prediction_time:: 0.080112 sec
#
#
# Eval:: MAE: 0.959744 RMSE: 1.251668
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2516678093229134
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.05 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.925248 sec
# prediction_time:: 0.073156 sec
#
#
# Eval:: MAE: 0.959839 RMSE: 1.25191
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2519095992260014
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.05 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.469542 sec
# prediction_time:: 0.080416 sec
#
#
# Eval:: MAE: 0.960976 RMSE: 1.251988
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2519878981467083
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.05 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.668170 sec
# prediction_time:: 0.077855 sec
#
#
# Eval:: MAE: 0.958784 RMSE: 1.248876
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2488755503136815
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.05 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.673419 sec
# prediction_time:: 0.082621 sec
#
#
# Eval:: MAE: 0.959364 RMSE: 1.250121
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.250121395372007
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.05 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.839233 sec
# prediction_time:: 0.088445 sec
#
#
# Eval:: MAE: 0.959108 RMSE: 1.25056
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2505600518302322
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.1 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.947275 sec
# prediction_time:: 0.069774 sec
#
#
# Eval:: MAE: 0.958508 RMSE: 1.250511
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2505108178918507
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.1 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.805854 sec
# prediction_time:: 0.082510 sec
#
#
# Eval:: MAE: 0.95604 RMSE: 1.249775
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.249774743595679
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.1 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.837193 sec
# prediction_time:: 0.079600 sec
#
#
# Eval:: MAE: 0.957542 RMSE: 1.24848
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2484800944446965
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.1 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.717597 sec
# prediction_time:: 0.074953 sec
#
#
# Eval:: MAE: 0.957193 RMSE: 1.247098
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2470978644230521
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.1 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.479029 sec
# prediction_time:: 0.083457 sec
#
#
# Eval:: MAE: 0.957277 RMSE: 1.247818
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2478184152754022
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.2 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 18.014951 sec
# prediction_time:: 0.084778 sec
#
#
# Eval:: MAE: 0.956921 RMSE: 1.247949
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.247949167851646
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.2 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.502581 sec
# prediction_time:: 0.077646 sec
#
#
# Eval:: MAE: 0.959546 RMSE: 1.253066
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2530661614280234
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.2 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.824967 sec
# prediction_time:: 0.084708 sec
#
#
# Eval:: MAE: 0.960227 RMSE: 1.251095
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2510946409169998
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.2 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.692877 sec
# prediction_time:: 0.079897 sec
#
#
# Eval:: MAE: 0.959289 RMSE: 1.248549
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2485487237599506
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.2 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.447761 sec
# prediction_time:: 0.084475 sec
#
#
# Eval:: MAE: 0.957419 RMSE: 1.249303
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2493025022365694
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.5 delta, 0.001 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.367074 sec
# prediction_time:: 0.082336 sec
#
#
# Eval:: MAE: 0.96177 RMSE: 1.253725
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2537245313365648
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.5 delta, 0.005 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.905071 sec
# prediction_time:: 0.078867 sec
#
#
# Eval:: MAE: 0.959708 RMSE: 1.252169
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2521694771411183
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.5 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 19.012172 sec
# prediction_time:: 0.078450 sec
#
#
# Eval:: MAE: 0.96016 RMSE: 1.252565
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2525650297540771
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.5 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 18.097772 sec
# prediction_time:: 0.078632 sec
#
#
# Eval:: MAE: 0.961095 RMSE: 1.252567
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2525669778759858
#
#
# Starting training on MatrixFactorization with 500 factors, 100 epochs, 0.5 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# test data:: 3200 users and 2540 items (16074 interactions) | sparsity:: 99.80%
#
# training_time:: 17.305214 sec
# prediction_time:: 0.075897 sec
#
#
# Eval:: MAE: 0.960339 RMSE: 1.251849
# 0 nan predictions from 16074 total
# MatrixFactorization with 500 factors: RMSE = 1.2518486749959152

# %% [markdown]
# ## Hibridização

# %%
def hybrid_predict(fbc_reviews, fbc_genre, w_reviews, w_genre):
    results = fbc_reviews.copy()
    results.rating = (fbc_reviews.rating * w_reviews) + (fbc_genre.rating * w_genre)
    return results

# %%
def run_hybrid_tests(train, test, weights):

    test_results_file = f'test_results_Hybrid-FBC.csv'

    real_ratings = eval.reset_index().rating
    to_test = eval.drop(columns=['rating'])    

    # Generate FBC by genre results
    movies_data = generate_genre_movies_data()
    generate_sim_file(movies_data, train, 'cosine')

    results_genre = fbc_predict(ItemAttributeKNN, train, to_test, 1, 'cosine', 'train.dat')
    results_genre = cold_start(results_genre, train, 'movie_id', 'user_id', 'average')
    results_genre = cold_start(results_genre, train, 'user_id', 'movie_id', 'average')

    results_genre = results_genre[['index', 'rating']]

    # Generate FBC by user reviews
    movies_data = generate_review_movies_data()
    generate_sim_file(movies_data, train, 'cosine')

    results_review = fbc_predict(ItemAttributeKNN, train, to_test, 1, 'cosine', 'train.dat')
    results_review = cold_start(results_review, train, 'movie_id', 'user_id', 'average')
    results_review = cold_start(results_review, train, 'user_id', 'movie_id', 'average')

    results_review = results_review[['index', 'rating']]

    for wa, wb in weights:

        res = hybrid_predict(results_review, results_genre, wa, wb)
        
        qtd_nan = res.rating.isna().sum()
        print(f"{qtd_nan} nan predictions from {res.shape[0]} total")
        
        predicted = res.rating

        used = np.logical_and(~real_ratings.isna(), ~predicted.isna())
        rmse = mean_squared_error(real_ratings[used], predicted[used], squared=False)

        msg = f"Hybrid-FBC with {wa} weight for reviews metadata prediction and {wb} for genres metadata prediction: RMSE = {rmse}"
        print(msg)

        with open(test_results_file, 'a') as f:
            data = f"Hybrid-FBC,{wa},{wb},{rmse}\n"
            f.write(data)
    
    files.download(test_results_file)

# %%
weights = [(0.05, 0.95), (0.1, 0.9), (0.15, 0.85), (0.2, 0.8), (0.25, 0.75),
           (0.3, 0.7), (0.35, 0.65), (0.4, 0.6), (0.45, 0.55), (0.5, 0.5),
           (0.55, 0.45), (0.6, 0.4), (0.65, 0.35), (0.7, 0.3), (0.75, 0.25),
           (0.8, 0.2), (0.85, 0.15), (0.9, 0.1), (0.95, 0.05)]

run_hybrid_tests(train, eval, weights)
# Out:
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 19.978293 sec
# prediction_time:: 47.370509 sec
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3679 users and 2930 items (37504 interactions) | sparsity:: 99.65%
# training_time:: 9.080787 sec
# prediction_time:: 50.270591 sec
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.05 weight for metadata prediction and 0.95 for genres metadata prediction: RMSE = 0.9945710835490648
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.1 weight for metadata prediction and 0.9 for genres metadata prediction: RMSE = 0.9942058996863784
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.15 weight for metadata prediction and 0.85 for genres metadata prediction: RMSE = 0.9938906294908005
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.2 weight for metadata prediction and 0.8 for genres metadata prediction: RMSE = 0.9936253204740793
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.25 weight for metadata prediction and 0.75 for genres metadata prediction: RMSE = 0.9934100126654614
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.3 weight for metadata prediction and 0.7 for genres metadata prediction: RMSE = 0.9932447385815572
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.35 weight for metadata prediction and 0.65 for genres metadata prediction: RMSE = 0.9931295232018216
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.4 weight for metadata prediction and 0.6 for genres metadata prediction: RMSE = 0.9930643839496952
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.45 weight for metadata prediction and 0.55 for genres metadata prediction: RMSE = 0.9930493306794361
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.5 weight for metadata prediction and 0.5 for genres metadata prediction: RMSE = 0.9930843656686691
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.55 weight for metadata prediction and 0.45 for genres metadata prediction: RMSE = 0.9931694836166626
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.6 weight for metadata prediction and 0.4 for genres metadata prediction: RMSE = 0.9933046716483375
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.65 weight for metadata prediction and 0.35 for genres metadata prediction: RMSE = 0.9934899093240018
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.7 weight for metadata prediction and 0.3 for genres metadata prediction: RMSE = 0.9937251686547912
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.75 weight for metadata prediction and 0.25 for genres metadata prediction: RMSE = 0.9940104141237915
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.8 weight for metadata prediction and 0.2 for genres metadata prediction: RMSE = 0.9943456027128034
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.85 weight for metadata prediction and 0.15 for genres metadata prediction: RMSE = 0.9947306839347035
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.9 weight for metadata prediction and 0.1 for genres metadata prediction: RMSE = 0.9951655998713462
# 4 nan predictions from 16074 total
# Hybrid-FBC with 0.95 weight for metadata prediction and 0.05 for genres metadata prediction: RMSE = 0.995650285216937

# %% [markdown]
# # Algorithms Evaluation

# %%
def read_result_file(exp, columns):
    results_dir = '/content/drive/MyDrive/Sistemas de Recomendação/Trabalho Individual/Resultados de testes'
    return pd.read_csv(f"{results_dir}/test_results_{exp}.csv", names=columns)

def write_evaluation_file(results, filename):
    results_dir = '/content/drive/MyDrive/Sistemas de Recomendação/Trabalho Individual/Resultados de avaliações'
    
    result_file = f"{results_dir}/{filename}.dat"
    results.to_csv(result_file, index=False)
    
    return result_file

# %% [markdown]
# ## Baseline

# %%
def predict_and_submit(train, test, u_const, i_const):
    base_train = train.copy()
    
    global_bias = train.rating.mean()
    base_train.rating = base_train.rating - global_bias
    
    results = baseline_predict(base_train, test, global_bias, u_const, i_const)
    results = results[['id', 'rating']]

    filename = f"baseline_algorithm_{u_const}_user_const_{i_const}_item_const"
    message = f"Testing baseline algorithm with {u_const} user const and {i_const} item const"


    results_file = write_evaluation_file(results, filename)

    print(f'Submiting {filename}...')
    # !kaggle competitions submit -c scc5966 -f "$results_file" -m "$message"

# %%
cols = ['algorithm', 'u_const', 'i_const', 'rmse']
res_base = read_result_file('Baseline', cols)

# %%
top_5 = res_base.sort_values('rmse').head(5) # TOP 5
for index, row in top_5.iterrows():
    u_const = row['u_const']
    i_const = row['i_const']

    predict_and_submit(df_train, df_test, u_const, i_const)
# Out:
# Starting training on baseline with 10 user bias and 5 item bias
# Submiting baseline_algorithm_10_user_const_5_item_const...
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:9138: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   sort=sort,
# 100% 89.4k/89.4k [00:00<00:00, 375kB/s]
# Successfully submitted to SCC5966
#
# Starting training on baseline with 10 user bias and 2 item bias
# Submiting baseline_algorithm_10_user_const_2_item_const...
# 100% 89.4k/89.4k [00:00<00:00, 419kB/s]
# Successfully submitted to SCC5966
#
# Starting training on baseline with 15 user bias and 5 item bias
# Submiting baseline_algorithm_15_user_const_5_item_const...
# 100% 89.5k/89.5k [00:00<00:00, 474kB/s]
# Successfully submitted to SCC5966
#
# Starting training on baseline with 15 user bias and 2 item bias
# Submiting baseline_algorithm_15_user_const_2_item_const...
# 100% 89.5k/89.5k [00:00<00:00, 458kB/s]
# Successfully submitted to SCC5966
#
# Starting training on baseline with 20 user bias and 2 item bias
# Submiting baseline_algorithm_20_user_const_2_item_const...
# 100% 89.5k/89.5k [00:00<00:00, 423kB/s]
# Successfully submitted to SCC5966

# %%
top_5
# Out:
#    algorithm  u_const  i_const      rmse
# 32  baseline       10        5  0.972644
# 31  baseline       10        2  0.973425
# 42  baseline       15        5  0.973482
# 41  baseline       15        2  0.973803
# 51  baseline       20        2  0.975236

# %% [markdown]
# ## FC

# %%
cols = ['algorithm', 'k_neighbors', 'similarity', 'cold_start', 'rmse']
res_fc = read_result_file('FC', cols)

res_fc_item = res_fc[res_fc.algorithm == 'ItemKNN']
res_fc_user = res_fc[res_fc.algorithm == 'UserKNN']

# %%
def predict_and_submit(func, train, test, k_neighbors, similarity, cold):
    results = fc_predict(func, train, test, k_neighbors, similarity, 'full_train.dat')

    results = cold_start(results, train, 'movie_id', 'user_id', cold)
    results = cold_start(results, train, 'user_id', 'movie_id', cold)

    results = results[['id', 'rating']]

    filename = f"{func.__name__}_{k_neighbors}_neighbors_{similarity}_sim_{cold}_coldstart"
    message = f"Testing {func.__name__} with {k_neighbors} neighbors, {similarity} similarity and {cold} for cold start"

    results_file = write_evaluation_file(results, filename)

    print(f'Submiting {filename}...')
    # !kaggle competitions submit -c scc5966 -f "$results_file" -m "$message"

# %% [markdown]
# ### Item kNN

# %%
top_5 = res_fc_item.sort_values('rmse').head(5) # TOP 5
for index, row in top_5.iterrows():
    knn = row['k_neighbors']
    sim = row['similarity']
    cold = row['cold_start']

    predict_and_submit(ItemKNN, df_train, df_test, knn, sim, cold)
# Out:
# Starting training on ItemKNN with 1 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 27.523827 sec
# prediction_time:: 168.605538 sec
# Submiting ItemKNN_1_neighbors_hamming_sim_average_coldstart...
# 100% 53.6k/53.6k [00:00<00:00, 283kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemKNN with 1 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 27.553903 sec
# prediction_time:: 168.275801 sec
# Submiting ItemKNN_1_neighbors_hamming_sim_mode_coldstart...
# 100% 52.1k/52.1k [00:00<00:00, 255kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 24.179585 sec
# prediction_time:: 174.988543 sec
# Submiting ItemKNN_1_neighbors_cosine_sim_average_coldstart...
# 100% 53.4k/53.4k [00:00<00:00, 283kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 24.561124 sec
# prediction_time:: 183.062561 sec
# Submiting ItemKNN_1_neighbors_cosine_sim_mode_coldstart...
# 100% 51.8k/51.8k [00:00<00:00, 240kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemKNN with 10 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > ItemKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 24.603102 sec
# prediction_time:: 190.566417 sec
# Submiting ItemKNN_10_neighbors_hamming_sim_average_coldstart...
# 100% 53.5k/53.5k [00:00<00:00, 292kB/s]
# Successfully submitted to SCC5966

# %%
top_5
# Out:
#    algorithm  k_neighbors similarity cold_start      rmse
# 12   ItemKNN            1    hamming    average  1.017807
# 13   ItemKNN            1    hamming       mode  1.022879
# 0    ItemKNN            1     cosine    average  1.102835
# 1    ItemKNN            1     cosine       mode  1.107517
# 14   ItemKNN           10    hamming    average  1.166886

# %% [markdown]
# ### User kNN

# %%
top_5 = res_fc_user.sort_values('rmse').head(5) # TOP 5
for index, row in top_5.iterrows():
    knn = row['k_neighbors']
    sim = row['similarity']
    cold = row['cold_start']

    predict_and_submit(UserKNN, df_train, df_test, knn, sim, cold)
# Out:
# Starting training on UserKNN with 500 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 24.709789 sec
# prediction_time:: 437.274205 sec
# Submiting UserKNN_500_neighbors_hamming_sim_average_coldstart...
# 100% 53.1k/53.1k [00:00<00:00, 267kB/s]
# Successfully submitted to SCC5966
#
# Starting training on UserKNN with 300 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 24.300260 sec
# prediction_time:: 293.674478 sec
# Submiting UserKNN_300_neighbors_hamming_sim_average_coldstart...
# 100% 52.7k/52.7k [00:00<00:00, 282kB/s]
# Successfully submitted to SCC5966
#
# Starting training on UserKNN with 150 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 25.041077 sec
# prediction_time:: 200.577354 sec
# Submiting UserKNN_150_neighbors_hamming_sim_average_coldstart...
# 100% 52.3k/52.3k [00:00<00:00, 300kB/s]
# Successfully submitted to SCC5966
#
# Starting training on UserKNN with 50 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 24.972911 sec
# prediction_time:: 158.651690 sec
# Submiting UserKNN_50_neighbors_hamming_sim_average_coldstart...
# 100% 52.9k/52.9k [00:00<00:00, 260kB/s]
# Successfully submitted to SCC5966
#
# Starting training on UserKNN with 500 neighbors and hamming similarity
# [Case Recommender: Rating Prediction > UserKNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 25.682496 sec
# prediction_time:: 433.207018 sec
# Submiting UserKNN_500_neighbors_hamming_sim_mode_coldstart...
# 100% 51.6k/51.6k [00:00<00:00, 219kB/s]
# Successfully submitted to SCC5966

# %%
top_5
# Out:
#    algorithm  k_neighbors similarity cold_start      rmse
# 58   UserKNN          500    hamming    average  0.997829
# 56   UserKNN          300    hamming    average  0.997829
# 54   UserKNN          150    hamming    average  0.997829
# 52   UserKNN           50    hamming    average  0.998431
# 59   UserKNN          500    hamming       mode  1.003002

# %% [markdown]
# ## FBC

# %%
def predict_and_submit(func, train, test, movies_data, k_neighbors, similarity, cold, metadata):

    generate_sim_file(movies_data, train, similarity)
    results = fbc_predict(func, train, test, k_neighbors, similarity, 'full_train.dat')

    results = cold_start(results, train, 'movie_id', 'user_id', cold)
    results = cold_start(results, train, 'user_id', 'movie_id', cold)

    results = results[['id', 'rating']]

    filename = f"{func.__name__}_{k_neighbors}_neighbors_{similarity}_sim_{cold}_coldstart_{metadata}_metadata"
    message = f"Testing {func.__name__} with {k_neighbors} neighbors, {similarity} similarity and {cold} for cold start using {metadata} metadata"

    results_file = write_evaluation_file(results, filename)

    print(f'Submiting {filename}...')
    # !kaggle competitions submit -c scc5966 -f "$results_file" -m "$message"

# %% [markdown]
# ### Genre Data

# %%
iaknn = read_result_file('FBC_Genre_Metadata', ['algorithm', 'k_neighbors', 'similarity', 'cold_start', 'rmse'])
movies_data = generate_genre_movies_data()

# %%
top_5 = iaknn.sort_values('rmse').head(5) # TOP 10

for index, row in top_5.iterrows():
    knn = row['k_neighbors']
    sim = row['similarity']
    cold = row['cold_start']

    predict_and_submit(ItemAttributeKNN, df_train, df_test, movies_data, knn, sim, cold, 'movies_genre')
# Out:
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 27.722649 sec
# prediction_time:: 172.321584 sec
# Submiting ItemAttributeKNN_1_neighbors_cosine_sim_average_coldstart...
# 100% 53.5k/53.5k [00:00<00:00, 266kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemAttributeKNN with 1 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 25.894890 sec
# prediction_time:: 161.316154 sec
# Submiting ItemAttributeKNN_1_neighbors_euclidean_sim_average_coldstart...
# 100% 53.5k/53.5k [00:00<00:00, 281kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemAttributeKNN with 1 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 23.730904 sec
# prediction_time:: 164.289517 sec
# Submiting ItemAttributeKNN_1_neighbors_manhattan_sim_average_coldstart...
# 100% 53.5k/53.5k [00:00<00:00, 268kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 24.437475 sec
# prediction_time:: 169.633796 sec
# Submiting ItemAttributeKNN_1_neighbors_cosine_sim_mode_coldstart...
# 100% 52.0k/52.0k [00:00<00:00, 234kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemAttributeKNN with 1 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 25.851974 sec
# prediction_time:: 165.069515 sec
# Submiting ItemAttributeKNN_1_neighbors_euclidean_sim_mode_coldstart...
# 100% 52.0k/52.0k [00:00<00:00, 282kB/s]
# Successfully submitted to SCC5966

# %%
top_5
# Out:
#            algorithm  k_neighbors similarity cold_start      rmse
# 0   ItemAttributeKNN            1     cosine    average  1.003617
# 12  ItemAttributeKNN            1  euclidean    average  1.003957
# 24  ItemAttributeKNN            1  manhattan    average  1.003957
# 1   ItemAttributeKNN            1     cosine       mode  1.008760
# 13  ItemAttributeKNN            1  euclidean       mode  1.009098

# %% [markdown]
# ### Reviews Data

# %%
cols = ['algorithm', 'k_neighbors', 'similarity', 'cold_start', 'rmse']
iaknn = read_result_file('FBC_Review_Metadata', cols)
movies_data = generate_review_movies_data()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
top_5 = iaknn.sort_values('rmse').head(5) # TOP 5

for index, row in top_5.iterrows():
    knn = row['k_neighbors']
    sim = row['similarity']
    cold = row['cold_start']

    predict_and_submit(ItemAttributeKNN, df_train, df_test, movies_data, knn, sim, cold, 'review_metadata')
# Out:
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 23.539009 sec
# prediction_time:: 167.829561 sec
# Submiting ItemAttributeKNN_1_neighbors_cosine_sim_average_coldstart_review_metadata_metadata...
# 100% 53.5k/53.5k [00:00<00:00, 282kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemAttributeKNN with 1 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 23.137151 sec
# prediction_time:: 165.228969 sec
# Submiting ItemAttributeKNN_1_neighbors_manhattan_sim_average_coldstart_review_metadata_metadata...
# 100% 53.3k/53.3k [00:00<00:00, 248kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemAttributeKNN with 1 neighbors and euclidean similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 22.806355 sec
# prediction_time:: 163.608213 sec
# Submiting ItemAttributeKNN_1_neighbors_euclidean_sim_average_coldstart_review_metadata_metadata...
# 100% 53.4k/53.4k [00:00<00:00, 285kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 24.655800 sec
# prediction_time:: 168.331686 sec
# Submiting ItemAttributeKNN_1_neighbors_cosine_sim_mode_coldstart_review_metadata_metadata...
# 100% 52.0k/52.0k [00:00<00:00, 283kB/s]
# Successfully submitted to SCC5966
#
# Starting training on ItemAttributeKNN with 1 neighbors and manhattan similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 22.837912 sec
# prediction_time:: 159.922560 sec
# Submiting ItemAttributeKNN_1_neighbors_manhattan_sim_mode_coldstart_review_metadata_metadata...
# 100% 51.8k/51.8k [00:00<00:00, 250kB/s]
# Successfully submitted to SCC5966

# %%
top_5
# Out:
#            algorithm  k_neighbors similarity cold_start      rmse
# 0   ItemAttributeKNN            1     cosine    average  1.004811
# 24  ItemAttributeKNN            1  manhattan    average  1.005569
# 12  ItemAttributeKNN            1  euclidean    average  1.005793
# 1   ItemAttributeKNN            1     cosine       mode  1.009948
# 25  ItemAttributeKNN            1  manhattan       mode  1.010702

# %% [markdown]
# ## Fatoração de Matrizes

# %% [markdown]
# ### SGD

# %%
def predict_and_submit(func, train, test, factors, epochs, delta, learn_rate):
    results = sgd_predict(func, train, test, factors, epochs, delta, learn_rate, 'full_train.dat', 'full_test.dat')

    results = results[['id', 'rating']]

    filename = f"SGD_{factors}_factors_{epochs}_epochs_{delta}_delta_{learn_rate}_learn_rate"
    message = f"Testing Stochastic Gradient Descent algorithm with {factors} factors, {epochs} epochs, {delta} delta and {learn_rate} learn rate"

    results_file = write_evaluation_file(results, filename)

    print(f'Submiting {filename}...')
    # !kaggle competitions submit -c scc5966 -f "$results_file" -m "$message"

# %%
cols = ['algorithm', 'factors', 'epochs', 'delta', 'learn_rate', 'rmse']
sgd = read_result_file('SGD', cols)

# %%
top_5 = sgd.sort_values('rmse').head(5) # TOP 5

for index, row in top_5.iterrows():
    factors = row['factors']
    epochs = row['epochs']
    delta = row['delta']
    lr = row['learn_rate']

    predict_and_submit(MatrixFactorization, df_train, df_test, factors, epochs, delta, lr)
# Out:
# Starting training on MatrixFactorization with 10 factors, 50 epochs, 0.01 delta, 0.01 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 122.140172 sec
# prediction_time:: 0.015579 sec
#
#
# Eval:: MAE: 1980.855348 RMSE: 2288.488537
# Submiting SGD_10_factors_50_epochs_0.01_delta_0.01_learn_rate...
# 100% 52.6k/52.6k [00:00<00:00, 55.4kB/s]
# Successfully submitted to SCC5966
#
# Starting training on MatrixFactorization with 10 factors, 15 epochs, 0.5 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 126.739363 sec
# prediction_time:: 0.015574 sec
#
#
# Eval:: MAE: 1980.860048 RMSE: 2288.493245
# Submiting SGD_10_factors_15_epochs_0.5_delta_0.03_learn_rate...
# 100% 52.7k/52.7k [00:01<00:00, 53.0kB/s]
# Successfully submitted to SCC5966
#
# Starting training on MatrixFactorization with 10 factors, 15 epochs, 0.1 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 123.606142 sec
# prediction_time:: 0.015366 sec
#
#
# Eval:: MAE: 1980.863033 RMSE: 2288.49491
# Submiting SGD_10_factors_15_epochs_0.1_delta_0.03_learn_rate...
# 100% 52.7k/52.7k [00:00<00:00, 59.4kB/s]
# Successfully submitted to SCC5966
#
# Starting training on MatrixFactorization with 10 factors, 20 epochs, 0.2 delta, 0.05 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 126.757555 sec
# prediction_time:: 0.016156 sec
#
#
# Eval:: MAE: 1980.854827 RMSE: 2288.488227
# Submiting SGD_10_factors_20_epochs_0.2_delta_0.05_learn_rate...
# 100% 52.7k/52.7k [00:00<00:00, 57.4kB/s]
# Successfully submitted to SCC5966
#
# Starting training on MatrixFactorization with 10 factors, 20 epochs, 0.05 delta, 0.03 learn_rate
# [Case Recommender: Rating Prediction > Matrix Factorization]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 125.513580 sec
# prediction_time:: 0.013195 sec
#
#
# Eval:: MAE: 1980.863766 RMSE: 2288.49542
# Submiting SGD_10_factors_20_epochs_0.05_delta_0.03_learn_rate...
# 100% 52.6k/52.6k [00:01<00:00, 50.5kB/s]
# Successfully submitted to SCC5966

# %%
top_5
# Out:
#                algorithm  factors  epochs  delta  learn_rate      rmse
# 787  MatrixFactorization       10      50   0.01        0.01  1.067373
# 718  MatrixFactorization       10      15   0.50        0.03  1.067717
# 708  MatrixFactorization       10      15   0.10        0.03  1.067731
# 744  MatrixFactorization       10      20   0.20        0.05  1.067954
# 733  MatrixFactorization       10      20   0.05        0.03  1.068040

# %% [markdown]
# ### SVD

# %%
def predict_and_submit(func, train, test, factors):
    results = svd_predict(func, train, test, factors, 'full_train.dat', 'full_test.dat')
    results = results[['id', 'rating']]

    filename = f"SVD_{factors}_factors"
    message = f"Testing SVD algorithm with {factors} factors"

    results_file = write_evaluation_file(results, filename)

    print(f'Submiting {filename}...')
    # !kaggle competitions submit -c scc5966 -f "$results_file" -m "$message"

# %%
cols = ['algorithm', 'factors', 'rmse']
svd = read_result_file('SVD', cols)

# %%
top_5 = svd.sort_values('rmse').head(5) # TOP 5

for index, row in top_5.iterrows():
    factors = row['factors']
    predict_and_submit(SVD, df_train, df_test, factors)
# Out:
# Starting training on SVD with 1 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 0.630391 sec
# prediction_time:: 0.011410 sec
#
#
# Eval:: MAE: 1980.605908 RMSE: 2288.269344
# Submiting SVD_1_factors...
# 100% 52.1k/52.1k [00:01<00:00, 48.5kB/s]
# Successfully submitted to SCC5966
#
# Starting training on SVD with 2 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 0.948915 sec
# prediction_time:: 0.012030 sec
#
#
# Eval:: MAE: 1980.572213 RMSE: 2288.23745
# Submiting SVD_2_factors...
# 100% 52.0k/52.0k [00:00<00:00, 54.7kB/s]
# Successfully submitted to SCC5966
#
# Starting training on SVD with 5 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 1.418578 sec
# prediction_time:: 0.013452 sec
#
#
# Eval:: MAE: 1980.513564 RMSE: 2288.194395
# Submiting SVD_5_factors...
# 100% 51.6k/51.6k [00:00<00:00, 56.2kB/s]
# Successfully submitted to SCC5966
#
# Starting training on SVD with 10 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 1.462573 sec
# prediction_time:: 0.013166 sec
#
#
# Eval:: MAE: 1980.448011 RMSE: 2288.143466
# Submiting SVD_10_factors...
# 100% 51.4k/51.4k [00:01<00:00, 48.9kB/s]
# Successfully submitted to SCC5966
#
# Starting training on SVD with 20 factors
# [Case Recommender: Rating Prediction > SVD]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# test data:: 418 users and 1611 items (3970 interactions) | sparsity:: 99.41%
#
# training_time:: 2.081200 sec
# prediction_time:: 0.012406 sec
#
#
# Eval:: MAE: 1980.403189 RMSE: 2288.109185
# Submiting SVD_20_factors...
# 100% 51.2k/51.2k [00:01<00:00, 48.4kB/s]
# Successfully submitted to SCC5966

# %%
top_5
# Out:
#   algorithm  factors      rmse
# 0       SVD        1  1.107041
# 1       SVD        2  1.107462
# 2       SVD        5  1.107909
# 3       SVD       10  1.111466
# 4       SVD       20  1.116066

# %% [markdown]
# ## Hibridização FBC

# %%
def predict_and_submit(results_reviews, results_genre, weight_review, weight_genre):

    results = hybrid_predict(results_reviews, results_genre, weight_review, weight_genre)
    results = results[['id', 'rating']]

    filename = f"Hybrid-FBC_{weight_review}_weight_review_metadata_{weight_genre}_weight_genre_metadata"
    message = f"Testing Hybrid-FBC with {weight_review} for FBC reviews metadata based ratings and {weight_genre} for FBC genre metadata based ratings"

    results_file = write_evaluation_file(results, filename)

    print(f'Submiting {filename}...')
    # !kaggle competitions submit -c scc5966 -f "$results_file" -m "$message"

    return

# %%
cols = ['algorithm', 'weight_reviews', 'weight_genres', 'rmse']
hyb = read_result_file('Hybrid-FBC', cols)

# %%
# Generate FBC by genre results
movies_data = generate_genre_movies_data()
generate_sim_file(movies_data, train, 'cosine')

results_genre = fbc_predict(ItemAttributeKNN, df_train, df_test, 1, 'cosine', 'full_train.dat')
results_genre = cold_start(results_genre, df_train, 'movie_id', 'user_id', 'average')
results_genre = cold_start(results_genre, df_train, 'user_id', 'movie_id', 'average')

results_genre = results_genre[['id', 'rating']]

# Generate FBC by user reviews
movies_data = generate_review_movies_data()
generate_sim_file(movies_data, train, 'cosine')

results_review = fbc_predict(ItemAttributeKNN, df_train, df_test, 1, 'cosine', 'full_train.dat')
results_review = cold_start(results_review, df_train, 'movie_id', 'user_id', 'average')
results_review = cold_start(results_review, df_train, 'user_id', 'movie_id', 'average')

results_review = results_review[['id', 'rating']]
# Out:
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 38.165143 sec
# prediction_time:: 185.773852 sec
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Starting training on ItemAttributeKNN with 1 neighbors and cosine similarity
# [Case Recommender: Rating Prediction > Item Attribute KNN Algorithm]
#
# train data:: 3952 users and 3562 items (535784 interactions) | sparsity:: 96.19%
# training_time:: 33.535511 sec
# prediction_time:: 185.517024 sec

# %%
top_5 = hyb.sort_values('rmse').head(5) # TOP 5

for index, row in top_5.iterrows():
    wr = row['weight_reviews']
    wg = row['weight_genres']

    predict_and_submit(results_review, results_genre, wr, wg)
# Out:
# Submiting Hybrid-FBC_0.45_weight_review_metadata_0.55_weight_genre_metadata...
# 100% 66.7k/66.7k [00:03<00:00, 22.7kB/s]
# Successfully submitted to SCC5966Submiting Hybrid-FBC_0.4_weight_review_metadata_0.6_weight_genre_metadata...
# 100% 57.7k/57.7k [00:02<00:00, 22.1kB/s]
# Successfully submitted to SCC5966Submiting Hybrid-FBC_0.5_weight_review_metadata_0.5_weight_genre_metadata...
# 100% 55.0k/55.0k [00:03<00:00, 17.1kB/s]
# Successfully submitted to SCC5966Submiting Hybrid-FBC_0.35_weight_review_metadata_0.65_weight_genre_metadata...
# 100% 59.8k/59.8k [00:01<00:00, 32.9kB/s]
# Successfully submitted to SCC5966Submiting Hybrid-FBC_0.55_weight_review_metadata_0.45_weight_genre_metadata...
# 100% 66.5k/66.5k [00:02<00:00, 31.5kB/s]
# Successfully submitted to SCC5966

# %%
top_5
# Out:
#      algorithm  weight_reviews  weight_genres      rmse
# 8   Hybrid-FBC            0.45           0.55  0.993049
# 7   Hybrid-FBC            0.40           0.60  0.993064
# 9   Hybrid-FBC            0.50           0.50  0.993084
# 6   Hybrid-FBC            0.35           0.65  0.993130
# 10  Hybrid-FBC            0.55           0.45  0.993169
